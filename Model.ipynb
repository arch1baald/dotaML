# %%
import pandas as pd
import pickle

# %%
df_matches = pd.read_csv('./data/dataset.csv', index_col=0)

# %%
df_matches.head()
# Out:
#    account_id  assists attack_type  camps_stacked  creeps_stacked  deaths  \
# 0    90882159        5      Ranged            0.0             0.0       4
# 1   114239371        6       Melee            0.0             0.0       6
# 2   148215639        7      Ranged            0.0             0.0       6
# 3   111189717        6       Melee            2.0             6.0       3
# 4   119576842        8      Ranged            0.0             0.0       5
#
#    denies  duration  first_blood_time  gold_per_min    ...      cm_enabled  \
# 0      12      1704                 0           400    ...            True
# 1       1      1704                 0           216    ...            True
# 2      13      1704                 0           408    ...            True
# 3      12      1704                 0           382    ...            True
# 4       3      1704                 0           204    ...            True
#
#    int_gain  legs  move_speed  pro_ban  pro_pick  pro_win  projectile_speed  \
# 0       2.5     2         295    218.0     244.0    124.0              1500
# 1       2.0     2         285     96.0     196.0     99.0               900
# 2       2.1     2         320     70.0     135.0     66.0              3000
# 3       1.6     2         315     13.0      21.0     13.0               900
# 4       2.5     2         300     40.0     155.0     69.0              1200
#
#    str_gain  turn_rate
# 0       2.0        0.5
# 1       3.5        0.6
# 2       2.1        0.6
# 3       2.6        0.5
# 4       2.2        0.5
#
# [5 rows x 251 columns]

# %%
'lane_role' in df_matches.columns
# Out:
# True

# %%
LANES = {
    'safe': 1,
    'mid': 2,
    'off': 3,
    'jungle': 4
}

# %%
df_matches['lane_role'].value_counts()
# Out:
# 2.0    2140
# 1.0    1932
# 3.0    1454
# 4.0      70
# Name: lane_role, dtype: int64

# %%
for col in df_matches.dtypes.items():
    print(col)
# Out:
# ('account_id', dtype('int64'))
# ('assists', dtype('int64'))
# ('attack_type', dtype('O'))
# ('camps_stacked', dtype('float64'))
# ('creeps_stacked', dtype('float64'))
# ('deaths', dtype('int64'))
# ('denies', dtype('int64'))
# ('duration', dtype('int64'))
# ('first_blood_time', dtype('int64'))
# ('gold_per_min', dtype('int64'))
# ('gold_spent', dtype('int64'))
# ('hero_damage', dtype('int64'))
# ('hero_healing', dtype('int64'))
# ('hero_id', dtype('int64'))
# ('is_roaming', dtype('bool'))
# ('kills', dtype('int64'))
# ('lane', dtype('float64'))
# ('lane_role', dtype('float64'))
# ('last_hits', dtype('int64'))
# ('leagueid', dtype('int64'))
# ('leaguename', dtype('O'))
# ('level', dtype('int64'))
# ('localized_name', dtype('O'))
# ('match_id', dtype('int64'))
# ('observers_placed', dtype('float64'))
# ('player_slot', dtype('int64'))
# ('primary_attr', dtype('O'))
# ('roshans_killed', dtype('float64'))
# ('rune_pickups', dtype('float64'))
# ('start_time', dtype('int64'))
# ('stuns', dtype('float64'))
# ('t_experience_cnt_10', dtype('float64'))
# ('t_experience_cnt_12', dtype('float64'))
# ('t_experience_cnt_15', dtype('float64'))
# ('t_experience_cnt_20', dtype('float64'))
# ('t_experience_cnt_25', dtype('float64'))
# ('t_experience_cnt_3', dtype('float64'))
# ('t_experience_cnt_30', dtype('float64'))
# ('t_experience_cnt_5', dtype('float64'))
# ('t_experience_cnt_8', dtype('float64'))
# ('t_gold_cnt_10', dtype('float64'))
# ('t_gold_cnt_12', dtype('float64'))
# ('t_gold_cnt_15', dtype('float64'))
# ('t_gold_cnt_20', dtype('float64'))
# ('t_gold_cnt_25', dtype('float64'))
# ('t_gold_cnt_3', dtype('float64'))
# ('t_gold_cnt_30', dtype('float64'))
# ('t_gold_cnt_5', dtype('float64'))
# ('t_gold_cnt_8', dtype('float64'))
# ('t_lasthits_cnt_10', dtype('float64'))
# ('t_lasthits_cnt_12', dtype('float64'))
# ('t_lasthits_cnt_15', dtype('float64'))
# ('t_lasthits_cnt_20', dtype('float64'))
# ('t_lasthits_cnt_25', dtype('float64'))
# ('t_lasthits_cnt_3', dtype('float64'))
# ('t_lasthits_cnt_30', dtype('float64'))
# ('t_lasthits_cnt_5', dtype('float64'))
# ('t_lasthits_cnt_8', dtype('float64'))
# ('team_id', dtype('float64'))
# ('teamfight_participation', dtype('float64'))
# ('tower_damage', dtype('int64'))
# ('towers_killed', dtype('float64'))
# ('win', dtype('bool'))
# ('xp_per_min', dtype('int64'))
# ('id', dtype('O'))
# ('datetime', dtype('O'))
# ('t_item_aether_lens', dtype('int64'))
# ('t_item_arcane_boots', dtype('int64'))
# ('t_item_black_king_bar', dtype('int64'))
# ('t_item_blade_mail', dtype('int64'))
# ('t_item_blink', dtype('int64'))
# ('t_item_boots', dtype('int64'))
# ('t_item_bottle', dtype('int64'))
# ('t_item_desolator', dtype('int64'))
# ('t_item_echo_sabre', dtype('int64'))
# ('t_item_force_staff', dtype('int64'))
# ('t_item_hand_of_midas', dtype('int64'))
# ('t_item_hurricane_pike', dtype('int64'))
# ('t_item_invis_sword', dtype('int64'))
# ('t_item_magic_wand', dtype('int64'))
# ('t_item_manta', dtype('int64'))
# ('t_item_phase_boots', dtype('int64'))
# ('t_item_power_treads', dtype('int64'))
# ('t_item_ring_of_aquila', dtype('int64'))
# ('t_item_silver_edge', dtype('int64'))
# ('t_item_sphere', dtype('int64'))
# ('t_item_tranquil_boots', dtype('int64'))
# ('t_item_travel_boots', dtype('int64'))
# ('t_item_ultimate_scepter', dtype('int64'))
# ('t_item_wind_lace', dtype('int64'))
# ('t_first_kill', dtype('float64'))
# ('pings', dtype('float64'))
# ('t_obs_0_cnt', dtype('float64'))
# ('t_obs_0_rpm', dtype('float64'))
# ('t_obs_12_cnt', dtype('float64'))
# ('t_obs_12_rpm', dtype('float64'))
# ('t_obs_15_cnt', dtype('float64'))
# ('t_obs_15_rpm', dtype('float64'))
# ('t_obs_18_cnt', dtype('float64'))
# ('t_obs_18_rpm', dtype('float64'))
# ('t_obs_21_cnt', dtype('float64'))
# ('t_obs_21_rpm', dtype('float64'))
# ('t_obs_24_cnt', dtype('float64'))
# ('t_obs_24_rpm', dtype('float64'))
# ('t_obs_27_cnt', dtype('float64'))
# ('t_obs_27_rpm', dtype('float64'))
# ('t_obs_30_cnt', dtype('float64'))
# ('t_obs_30_rpm', dtype('float64'))
# ('t_obs_3_cnt', dtype('float64'))
# ('t_obs_3_rpm', dtype('float64'))
# ('t_obs_6_cnt', dtype('float64'))
# ('t_obs_6_rpm', dtype('float64'))
# ('t_obs_9_cnt', dtype('float64'))
# ('t_obs_9_rpm', dtype('float64'))
# ('t_sen_0_cnt', dtype('float64'))
# ('t_sen_0_rpm', dtype('float64'))
# ('t_sen_12_cnt', dtype('float64'))
# ('t_sen_12_rpm', dtype('float64'))
# ('t_sen_15_cnt', dtype('float64'))
# ('t_sen_15_rpm', dtype('float64'))
# ('t_sen_18_cnt', dtype('float64'))
# ('t_sen_18_rpm', dtype('float64'))
# ('t_sen_21_cnt', dtype('float64'))
# ('t_sen_21_rpm', dtype('float64'))
# ('t_sen_24_cnt', dtype('float64'))
# ('t_sen_24_rpm', dtype('float64'))
# ('t_sen_27_cnt', dtype('float64'))
# ('t_sen_27_rpm', dtype('float64'))
# ('t_sen_30_cnt', dtype('float64'))
# ('t_sen_30_rpm', dtype('float64'))
# ('t_sen_3_cnt', dtype('float64'))
# ('t_sen_3_rpm', dtype('float64'))
# ('t_sen_6_cnt', dtype('float64'))
# ('t_sen_6_rpm', dtype('float64'))
# ('t_sen_9_cnt', dtype('float64'))
# ('t_sen_9_rpm', dtype('float64'))
# ('t_runes_0_cnt', dtype('float64'))
# ('t_runes_0_rpm', dtype('float64'))
# ('t_runes_12_cnt', dtype('float64'))
# ('t_runes_12_rpm', dtype('float64'))
# ('t_runes_15_cnt', dtype('float64'))
# ('t_runes_15_rpm', dtype('float64'))
# ('t_runes_18_cnt', dtype('float64'))
# ('t_runes_18_rpm', dtype('float64'))
# ('t_runes_21_cnt', dtype('float64'))
# ('t_runes_21_rpm', dtype('float64'))
# ('t_runes_24_cnt', dtype('float64'))
# ('t_runes_24_rpm', dtype('float64'))
# ('t_runes_27_cnt', dtype('float64'))
# ('t_runes_27_rpm', dtype('float64'))
# ('t_runes_30_cnt', dtype('float64'))
# ('t_runes_30_rpm', dtype('float64'))
# ('t_runes_3_cnt', dtype('float64'))
# ('t_runes_3_rpm', dtype('float64'))
# ('t_runes_6_cnt', dtype('float64'))
# ('t_runes_6_rpm', dtype('float64'))
# ('t_runes_9_cnt', dtype('float64'))
# ('t_runes_9_rpm', dtype('float64'))
# ('t_kills_0_cnt', dtype('float64'))
# ('t_kills_0_rpm', dtype('float64'))
# ('t_kills_12_cnt', dtype('float64'))
# ('t_kills_12_rpm', dtype('float64'))
# ('t_kills_15_cnt', dtype('float64'))
# ('t_kills_15_rpm', dtype('float64'))
# ('t_kills_18_cnt', dtype('float64'))
# ('t_kills_18_rpm', dtype('float64'))
# ('t_kills_21_cnt', dtype('float64'))
# ('t_kills_21_rpm', dtype('float64'))
# ('t_kills_24_cnt', dtype('float64'))
# ('t_kills_24_rpm', dtype('float64'))
# ('t_kills_27_cnt', dtype('float64'))
# ('t_kills_27_rpm', dtype('float64'))
# ('t_kills_30_cnt', dtype('float64'))
# ('t_kills_30_rpm', dtype('float64'))
# ('t_kills_3_cnt', dtype('float64'))
# ('t_kills_3_rpm', dtype('float64'))
# ('t_kills_6_cnt', dtype('float64'))
# ('t_kills_6_rpm', dtype('float64'))
# ('t_kills_9_cnt', dtype('float64'))
# ('t_kills_9_rpm', dtype('float64'))
# ('gold_reason_0', dtype('float64'))
# ('gold_reason_1', dtype('float64'))
# ('gold_reason_11', dtype('float64'))
# ('gold_reason_12', dtype('float64'))
# ('gold_reason_13', dtype('float64'))
# ('gold_reason_14', dtype('float64'))
# ('gold_reason_15', dtype('float64'))
# ('gold_reason_2', dtype('float64'))
# ('gold_reason_5', dtype('float64'))
# ('gold_reason_6', dtype('float64'))
# ('xp_reason_0', dtype('float64'))
# ('xp_reason_1', dtype('float64'))
# ('xp_reason_2', dtype('float64'))
# ('xp_reason_3', dtype('float64'))
# ('kill_streak_10', dtype('float64'))
# ('kill_streak_11', dtype('float64'))
# ('kill_streak_3', dtype('float64'))
# ('kill_streak_4', dtype('float64'))
# ('kill_streak_5', dtype('float64'))
# ('kill_streak_6', dtype('float64'))
# ('kill_streak_7', dtype('float64'))
# ('kill_streak_8', dtype('float64'))
# ('kill_streak_9', dtype('float64'))
# ('multi_kill_2', dtype('float64'))
# ('multi_kill_3', dtype('float64'))
# ('multi_kill_4', dtype('float64'))
# ('multi_kill_5', dtype('float64'))
# ('multi_kill_6', dtype('float64'))
# ('hero_role_carry', dtype('float64'))
# ('hero_role_disabler', dtype('float64'))
# ('hero_role_durable', dtype('float64'))
# ('hero_role_escape', dtype('float64'))
# ('hero_role_initiator', dtype('float64'))
# ('hero_role_jungler', dtype('float64'))
# ('hero_role_nuker', dtype('float64'))
# ('hero_role_pusher', dtype('float64'))
# ('hero_role_support', dtype('float64'))
# ('1000_pick', dtype('int64'))
# ('1000_win', dtype('int64'))
# ('2000_pick', dtype('int64'))
# ('2000_win', dtype('int64'))
# ('3000_pick', dtype('int64'))
# ('3000_win', dtype('int64'))
# ('4000_pick', dtype('int64'))
# ('4000_win', dtype('int64'))
# ('5000_pick', dtype('int64'))
# ('5000_win', dtype('int64'))
# ('agi_gain', dtype('float64'))
# ('attack_range', dtype('int64'))
# ('attack_rate', dtype('float64'))
# ('base_agi', dtype('int64'))
# ('base_armor', dtype('float64'))
# ('base_attack_max', dtype('int64'))
# ('base_attack_min', dtype('int64'))
# ('base_health', dtype('int64'))
# ('base_health_regen', dtype('float64'))
# ('base_int', dtype('int64'))
# ('base_mana', dtype('int64'))
# ('base_mana_regen', dtype('float64'))
# ('base_mr', dtype('int64'))
# ('base_str', dtype('int64'))
# ('cm_enabled', dtype('bool'))
# ('int_gain', dtype('float64'))
# ('legs', dtype('int64'))
# ('move_speed', dtype('int64'))
# ('pro_ban', dtype('float64'))
# ('pro_pick', dtype('float64'))
# ('pro_win', dtype('float64'))
# ('projectile_speed', dtype('int64'))
# ('str_gain', dtype('float64'))
# ('turn_rate', dtype('float64'))

# %%
id_columns = [
    'hero_id', 'match_id', 'account_id', 'team_id',
    'start_time', 'id', 'datetime', 'leaguename',
    'win'
]
categorical_columns = [c for c in df_matches.columns if df_matches[c].dtype.name == 'object' and c not in id_columns]
numerical_columns   = [c for c in df_matches.columns if df_matches[c].dtype.name != 'object' and c not in id_columns]
valid_columns = numerical_columns + categorical_columns

# %% [markdown]
# ## Transform

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %% [markdown]
# ### Drop id columns

# %%
X = df_matches[valid_columns]
y = df_matches['win']

# %% [markdown]
# ### One-hot encoding

# %%
df_dummies = pd.get_dummies(X[categorical_columns])
binary_columns = df_dummies.columns
X = pd.concat([X, df_dummies], axis = 1)
X.drop(categorical_columns, axis=1, inplace=True)

# %% [markdown]
# ### Data Partition

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 12345)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 
print(N_train, N_test)
# Out:
# 3917 1679

# %%
lm = LogisticRegression(penalty = 'l1', C = 1, fit_intercept=False)
lm.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=False,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print("Train accuracy = %s" %metrics.accuracy_score(y_train, lm.predict(X_train)))
print("Test accuracy = %s" %metrics.accuracy_score(y_test, lm.predict(X_test)))

print("Train AUC = %s" %metrics.roc_auc_score(y_train, lm.predict_proba(X_train)[:,1]))
print("Test AUC = %s" %metrics.roc_auc_score(y_test, lm.predict_proba(X_test)[:,1]))

print("Train Recall = %s" %metrics.recall_score(y_train, lm.predict(X_train)))
print("Test Recall = %s" %metrics.recall_score(y_test, lm.predict(X_test)))

print("Train Precision = %s" %metrics.precision_score(y_train, lm.predict(X_train)))
print("Test Precision = %s" %metrics.precision_score(y_test, lm.predict(X_test)))
# Out:
# Train accuracy = 0.983660965024
# Test accuracy = 0.95771292436
# Train AUC = 0.99878770539
# Test AUC = 0.989698992089
# Train Recall = 0.985707244948
# Test Recall = 0.961152882206
# Train Precision = 0.982800982801
# Test Precision = 0.950433705081

# %%
model = {}
for role, df_role in df_matches.groupby('lane_role'):
    print('Model for role: {}'.format(role))
    X = df_role[valid_columns]
    y = df_role['win']
    
    df_dummies = pd.get_dummies(X[categorical_columns])
    binary_columns = df_dummies.columns
    X = pd.concat([X, df_dummies], axis = 1)
    X.drop(categorical_columns, axis=1, inplace=True)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 12345)
    N_train, _ = X_train.shape 
    N_test,  _ = X_test.shape 
    print(N_train, N_test)
    
    lm = LogisticRegression(penalty = 'l1', C = 1, fit_intercept=False)
    lm.fit(X_train, y_train)
    model[role] = lm
    
    print("Train accuracy = %s" %metrics.accuracy_score(y_train, lm.predict(X_train)))
    print("Test accuracy = %s" %metrics.accuracy_score(y_test, lm.predict(X_test)))

    print("Train AUC = %s" %metrics.roc_auc_score(y_train, lm.predict_proba(X_train)[:,1]))
    print("Test AUC = %s" %metrics.roc_auc_score(y_test, lm.predict_proba(X_test)[:,1]))

    print("Train Recall = %s" %metrics.recall_score(y_train, lm.predict(X_train)))
    print("Test Recall = %s" %metrics.recall_score(y_test, lm.predict(X_test)))

    print("Train Precision = %s" %metrics.precision_score(y_train, lm.predict(X_train)))
    print("Test Precision = %s" %metrics.precision_score(y_test, lm.predict(X_test)))
    
    print()
# Out:
# Model for role: 1.0
# 1352 580
# Train accuracy = 1.0
# Test accuracy = 0.929310344828
# Train AUC = 1.0
# Test AUC = 0.974701159679
# Train Recall = 1.0
# Test Recall = 0.926315789474
# Train Precision = 1.0
# Test Precision = 0.929577464789
#
# Model for role: 2.0
# 1498 642
# Train accuracy = 1.0
# Test accuracy = 0.933021806854
# Train AUC = 1.0
# Test AUC = 0.972606197096
# Train Recall = 1.0
# Test Recall = 0.953987730061
# Train Precision = 1.0
# Test Precision = 0.917404129794
#
# Model for role: 3.0
# 1017 437
# Train accuracy = 1.0
# Test accuracy = 0.949656750572
# Train AUC = 1.0
# Test AUC = 0.973769117955
# Train Recall = 1.0
# Test Recall = 0.944186046512
# Train Precision = 1.0
# Test Precision = 0.953051643192
#
# Model for role: 4.0
# 49 21
# Train accuracy = 1.0
# Test accuracy = 0.904761904762
# Train AUC = 1.0
# Test AUC = 0.990384615385
# Train Recall = 1.0
# Test Recall = 0.923076923077
# Train Precision = 1.0
# Test Precision = 0.923076923077

# %%
import os

# %%
for role, model_obj in model.items():
    file_name = 'model_{}.sklearn'.format(role)
    file_path = os.path.join(os.path.abspath('data'), file_name)
    with open(file_path, 'wb') as model_file:
        pickle.dump(model_obj, model_file)
