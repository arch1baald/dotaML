# %% [markdown]
# # Application of Machine Learning Methods to Analysis of Cyber-Sport Events
# ## Dmitry Savostyanov, 131
#
# ## Витрина данных по участникам Kiev Major
#
# ## Финальный файл скрипта: ABT_[DATE].csv
#
# В данном скрипте представлена таблица по командам, которые указаны в файле Dota Features & Snippets - Roles.csv за период с 1 января 2017 года по сегодняшний день. Строка таблицы - информация о матче на уровне игрока. Т.е. если между IG и LGD был матч с match_id = 12345, то таблица содержит 10 записей с данным идентификаторм для каждого конкретного account_id.

# %%
import urllib2
import json
import random
import datetime

import math 
import pandas as pd 
import numpy as np 
import sklearn 
import matplotlib.pyplot as plt 
from sklearn import svm, datasets 
# %matplotlib inline
plt.style.use('ggplot')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-221c7d0077d5> in <module>()
# ----> 1 import urllib2
#       2 import json
#       3 import random
#       4 import datetime
#       5
#
# ImportError: No module named 'urllib2'

# %%
# urlQuery = "https://api.opendota.com/api/explorer?sql=SELECT%0D%0A%0D%0A%0D%0A--%20Basic%20table%0D%0Amatches.match_id%2C%0D%0Aplayer_matches.account_id%2C%0D%0Ateams.team_id%2C%0D%0Amatches.leagueid%2C%0D%0Aleagues.name%20leaguename%2C%0D%0Amatches.start_time%2C%0D%0Aplayer_matches.hero_id%2C%0D%0Aplayer_matches.player_slot%2C%0D%0A((player_matches.player_slot%20%3C%20128)%20%3D%20matches.radiant_win)%20win%2C%0D%0A((player_matches.player_slot%20%3C%20128)%20%3D%20true)%20radiant%2C%20--new%0D%0A((player_matches.player_slot%20%3C%20128)%20%3D%20false)%20dire%2C%20--new%0D%0Aplayer_matches.kills%2C%0D%0Aplayer_matches.deaths%2C%0D%0Aplayer_matches.assists%2C%0D%0Aplayer_matches.gold_per_min%20%2C%0D%0Aplayer_matches.xp_per_min%20%2C%0D%0Aplayer_matches.gold_spent%20%2C%0D%0Aplayer_matches.hero_damage%20%2C%0D%0Aplayer_matches.tower_damage%20%2C%0D%0Aplayer_matches.stuns%20%2C%0D%0Aplayer_matches.creeps_stacked%20%2C%0D%0Aplayer_matches.camps_stacked%20%2C%0D%0Aplayer_matches.hero_healing%20%2C%0D%0Aplayer_matches.last_hits%2C%0D%0Aplayer_matches.denies%2C%0D%0Aplayer_matches.level%2C%0D%0Amatches.duration%2C%0D%0Amatches.cluster%2C%0D%0Amatches.first_blood_time%2C%0D%0A%0D%0A--timeStamp%20variables%0D%0Aplayer_matches.gold_t%5B3%5D%20t_Gold_cnt_3%2C%0D%0Aplayer_matches.gold_t%5B5%5D%20t_Gold_cnt_5%2C%0D%0Aplayer_matches.gold_t%5B8%5D%20t_Gold_cnt_8%2C%0D%0Aplayer_matches.gold_t%5B10%5D%20t_Gold_cnt_10%2C%0D%0Aplayer_matches.gold_t%5B12%5D%20t_Gold_cnt_12%2C%0D%0Aplayer_matches.gold_t%5B15%5D%20t_Gold_cnt_15%2C%0D%0Aplayer_matches.gold_t%5B20%5D%20t_Gold_cnt_20%2C%0D%0Aplayer_matches.gold_t%5B25%5D%20t_Gold_cnt_25%2C%0D%0Aplayer_matches.gold_t%5B30%5D%20t_Gold_cnt_30%2C%0D%0A%0D%0Aplayer_matches.lh_t%5B3%5D%20t_LastHits_cnt_3%2C%0D%0Aplayer_matches.lh_t%5B5%5D%20t_LastHits_cnt_5%2C%0D%0Aplayer_matches.lh_t%5B8%5D%20t_LastHits_cnt_8%2C%0D%0Aplayer_matches.lh_t%5B10%5D%20t_LastHits_cnt_10%2C%0D%0Aplayer_matches.lh_t%5B12%5D%20t_LastHits_cnt_12%2C%0D%0Aplayer_matches.lh_t%5B15%5D%20t_LastHits_cnt_15%2C%0D%0Aplayer_matches.lh_t%5B20%5D%20t_LastHits_cnt_20%2C%0D%0Aplayer_matches.lh_t%5B25%5D%20t_LastHits_cnt_25%2C%0D%0Aplayer_matches.lh_t%5B30%5D%20t_LastHits_cnt_30%2C%0D%0A%0D%0Aplayer_matches.xp_t%5B3%5D%20t_Experience_cnt_3%2C%0D%0Aplayer_matches.xp_t%5B5%5D%20t_Experience_cnt_5%2C%0D%0Aplayer_matches.xp_t%5B8%5D%20t_Experience_cnt_8%2C%0D%0Aplayer_matches.xp_t%5B10%5D%20t_Experience_cnt_10%2C%0D%0Aplayer_matches.xp_t%5B12%5D%20t_Experience_cnt_12%2C%0D%0Aplayer_matches.xp_t%5B15%5D%20t_Experience_cnt_15%2C%0D%0Aplayer_matches.xp_t%5B20%5D%20t_Experience_cnt_20%2C%0D%0Aplayer_matches.xp_t%5B25%5D%20t_Experience_cnt_25%2C%0D%0Aplayer_matches.xp_t%5B30%5D%20t_Experience_cnt_30%2C%0D%0A%0D%0Aplayer_matches.pings%20ping_log%2C%0D%0Aplayer_matches.obs_log%2C%0D%0Aplayer_matches.sen_log%2C%0D%0Aplayer_matches.runes_log%2C%0D%0Aplayer_matches.kills_log%2C%0D%0Aplayer_matches.buyback_log%2C%0D%0A%0D%0A--table_heroStats%0D%0Aheroes.localized_name%2C%0D%0Aheroes.attack_type%2C%0D%0Aheroes.primary_attr%2C%0D%0Aheroes.roles%20role_log%2C%0D%0A%0D%0A--purchase_log%0D%0Aplayer_matches.purchase_log%0D%0A%0D%0AFROM%20matches%0D%0AJOIN%20match_patch%20using(match_id)%0D%0AJOIN%20leagues%20using(leagueid)%0D%0AJOIN%20player_matches%20using(match_id)%0D%0ALEFT%20JOIN%20notable_players%20using(account_id)%0D%0ALEFT%20JOIN%20teams%20using(team_id)%0D%0AJOIN%20heroes%20ON%20player_matches.hero_id%20%3D%20heroes.id%0D%0A%0D%0AJOIN%0D%0A(%0D%0A%20%20%20%20SELECT%0D%0A%20%20%20%20%0D%0A%20%20%20%20DISTINCT%20matches.match_id%0D%0A%20%20%20%20%0D%0A%20%20%20%20FROM%20matches%0D%0A%20%20%20%20JOIN%20match_patch%20using(match_id)%0D%0A%20%20%20%20JOIN%20leagues%20using(leagueid)%0D%0A%20%20%20%20JOIN%20player_matches%20using(match_id)%0D%0A%20%20%20%20LEFT%20JOIN%20notable_players%20using(account_id)%0D%0A%20%20%20%20LEFT%20JOIN%20teams%20using(team_id)%0D%0A%20%20%20%20JOIN%20heroes%20ON%20player_matches.hero_id%20%3D%20heroes.id%0D%0A%20%20%20%20%0D%0A%20%20%20%20WHERE%20TRUE%0D%0A%20%20%20%20AND%20teams.team_id%20in%0D%0A%20%20%20%20%20%20%20%20(%0D%0A%20%20%20%20%20%20%20%20%20%205%2C%0D%0A%20%20%20%20%09%20%2026%2C%0D%0A%20%20%20%20%09%20%2039%2C%0D%0A%20%20%20%20%09%20%202163%2C%0D%0A%20%20%20%20%09%20%201375614%2C%0D%0A%20%20%20%20%09%20%201836806%2C%0D%0A%20%20%20%20%09%20%201883502%2C%0D%0A%20%20%20%20%09%20%202108395%2C%0D%0A%20%20%20%20%09%20%202512249%2C%0D%0A%20%20%20%20%09%20%202586976%2C%0D%0A%20%20%20%20%09%20%202640025%2C%0D%0A%20%20%20%20%09%20%202642171%2C%0D%0A%20%20%20%20%09%20%203326875%2C%0D%0A%20%20%20%20%09%20%203722973%2C%0D%0A%20%20%20%20%09%20%203580606%2C%0D%0A%20%20%20%20%09%20%203547682%2C%0D%0A%20%20%20%20%09%20%204253054%2C%0D%0A%20%20%20%20%09%20%204251435%2C%0D%0A%20%20%20%20%09%20%201838315%0D%0A%20%20%20%20%20%20%20%20)%0D%0A%20%20%20%20AND%20matches.start_time%20%3E%3D%201483218000%0D%0A%20%20%20%20ORDER%20BY%20matches.match_id%20DESC%20NULLS%20LAST%0D%0A%20%20%20%20LIMIT%201000%0D%0A)%20t1%20ON%20matches.match_id%20%3D%20t1.match_id%0D%0A%0D%0A%0D%0AWHERE%20TRUE%0D%0AAND%20teams.team_id%20!%3D%200%0D%0AAND%20matches.start_time%20%3E%3D%201483218000%0D%0AORDER%20BY%20matches.match_id%20DESC%20NULLS%20LAST"

# %%
urlQuery = "https://api.opendota.com/api/explorer?sql=SELECT%0A%0A%0A--%20Basic%20table%0Amatches.match_id%2C%0Aplayer_matches.account_id%2C%0Ateams.team_id%2C%0Amatches.leagueid%2C%0Aleagues.name%20leaguename%2C%0Amatches.start_time%2C%0Aplayer_matches.hero_id%2C%0Aplayer_matches.player_slot%2C%0A((player_matches.player_slot%20%3C%20128)%20%3D%20matches.radiant_win)%20win%2C%0A((player_matches.player_slot%20%3C%20128)%20%3D%20true)%20radiant%2C%20--new%0A((player_matches.player_slot%20%3C%20128)%20%3D%20false)%20dire%2C%20--new%0Aplayer_matches.kills%2C%0Aplayer_matches.deaths%2C%0Aplayer_matches.assists%2C%0Aplayer_matches.gold_per_min%20%2C%0Aplayer_matches.xp_per_min%20%2C%0Aplayer_matches.gold_spent%20%2C%0Aplayer_matches.hero_damage%20%2C%0Aplayer_matches.tower_damage%20%2C%0Aplayer_matches.stuns%20%2C%0Aplayer_matches.creeps_stacked%20%2C%0Aplayer_matches.camps_stacked%20%2C%0Aplayer_matches.hero_healing%20%2C%0Aplayer_matches.last_hits%2C%0Aplayer_matches.denies%2C%0Aplayer_matches.level%2C%0Amatches.duration%2C%0Amatches.cluster%2C%0Amatches.first_blood_time%2C%0A%0A--timeStamp%20variables%0Aplayer_matches.gold_t%5B3%5D%20t_Gold_cnt_3%2C%0Aplayer_matches.gold_t%5B5%5D%20t_Gold_cnt_5%2C%0Aplayer_matches.gold_t%5B8%5D%20t_Gold_cnt_8%2C%0Aplayer_matches.gold_t%5B10%5D%20t_Gold_cnt_10%2C%0Aplayer_matches.gold_t%5B12%5D%20t_Gold_cnt_12%2C%0Aplayer_matches.gold_t%5B15%5D%20t_Gold_cnt_15%2C%0Aplayer_matches.gold_t%5B20%5D%20t_Gold_cnt_20%2C%0Aplayer_matches.gold_t%5B25%5D%20t_Gold_cnt_25%2C%0Aplayer_matches.gold_t%5B30%5D%20t_Gold_cnt_30%2C%0A%0Aplayer_matches.lh_t%5B3%5D%20t_LastHits_cnt_3%2C%0Aplayer_matches.lh_t%5B5%5D%20t_LastHits_cnt_5%2C%0Aplayer_matches.lh_t%5B8%5D%20t_LastHits_cnt_8%2C%0Aplayer_matches.lh_t%5B10%5D%20t_LastHits_cnt_10%2C%0Aplayer_matches.lh_t%5B12%5D%20t_LastHits_cnt_12%2C%0Aplayer_matches.lh_t%5B15%5D%20t_LastHits_cnt_15%2C%0Aplayer_matches.lh_t%5B20%5D%20t_LastHits_cnt_20%2C%0Aplayer_matches.lh_t%5B25%5D%20t_LastHits_cnt_25%2C%0Aplayer_matches.lh_t%5B30%5D%20t_LastHits_cnt_30%2C%0A%0Aplayer_matches.xp_t%5B3%5D%20t_Experience_cnt_3%2C%0Aplayer_matches.xp_t%5B5%5D%20t_Experience_cnt_5%2C%0Aplayer_matches.xp_t%5B8%5D%20t_Experience_cnt_8%2C%0Aplayer_matches.xp_t%5B10%5D%20t_Experience_cnt_10%2C%0Aplayer_matches.xp_t%5B12%5D%20t_Experience_cnt_12%2C%0Aplayer_matches.xp_t%5B15%5D%20t_Experience_cnt_15%2C%0Aplayer_matches.xp_t%5B20%5D%20t_Experience_cnt_20%2C%0Aplayer_matches.xp_t%5B25%5D%20t_Experience_cnt_25%2C%0Aplayer_matches.xp_t%5B30%5D%20t_Experience_cnt_30%2C%0A%0Aplayer_matches.pings%20ping_log%2C%0Aplayer_matches.obs_log%2C%0Aplayer_matches.sen_log%2C%0Aplayer_matches.runes_log%2C%0Aplayer_matches.kills_log%2C%0Aplayer_matches.buyback_log%2C%0A%0A--table_heroStats%0Aheroes.localized_name%2C%0Aheroes.attack_type%2C%0Aheroes.primary_attr%2C%0Aheroes.roles%20role_log%2C%0A%0A--purchase_log%0Aplayer_matches.purchase_log%0A%0AFROM%20matches%0AJOIN%20match_patch%20using(match_id)%0AJOIN%20leagues%20using(leagueid)%0AJOIN%20player_matches%20using(match_id)%0ALEFT%20JOIN%20notable_players%20using(account_id)%0ALEFT%20JOIN%20teams%20using(team_id)%0AJOIN%20heroes%20ON%20player_matches.hero_id%20%3D%20heroes.id%0A%0AJOIN%0A(%0A%20%20%20%20SELECT%0A%20%20%20%20%0A%20%20%20%20DISTINCT%20matches.match_id%0A%20%20%20%20%0A%20%20%20%20FROM%20matches%0A%20%20%20%20JOIN%20match_patch%20using(match_id)%0A%20%20%20%20JOIN%20leagues%20using(leagueid)%0A%20%20%20%20JOIN%20player_matches%20using(match_id)%0A%20%20%20%20LEFT%20JOIN%20notable_players%20using(account_id)%0A%20%20%20%20LEFT%20JOIN%20teams%20using(team_id)%0A%20%20%20%20JOIN%20heroes%20ON%20player_matches.hero_id%20%3D%20heroes.id%0A%20%20%20%20%0A%20%20%20%20WHERE%20TRUE%0A%20%20%20%20AND%20teams.team_id%20in%0A%20%20%20%20%20%20%20%20(%0A%20%20%20%20%20%20%20%20%20%205%2C%0A%20%20%20%20%09%20%2026%2C%0A%20%20%20%20%09%20%2039%2C%0A%20%20%20%20%09%20%202163%2C%0A%20%20%20%20%09%20%201375614%2C%0A%20%20%20%20%09%20%201836806%2C%0A%20%20%20%20%09%20%201883502%2C%0A%20%20%20%20%09%20%202108395%2C%0A%20%20%20%20%09%20%202512249%2C%0A%20%20%20%20%09%20%202586976%2C%0A%20%20%20%20%09%20%202640025%2C%0A%20%20%20%20%09%20%202642171%2C%0A%20%20%20%20%09%20%203326875%2C%0A%20%20%20%20%09%20%203722973%2C%0A%20%20%20%20%09%20%203580606%2C%0A%20%20%20%20%09%20%203547682%2C%0A%20%20%20%20%09%20%204253054%2C%0A%20%20%20%20%09%20%204251435%2C%0A%20%20%20%20%09%20%201838315%0A%20%20%20%20%20%20%20%20)%0A%20%20%20%20AND%20matches.start_time%20%3E%3D%201483218000%0A%20%20%20%20ORDER%20BY%20matches.match_id%20DESC%20NULLS%20LAST%0A%20%20%20%20LIMIT%201000%0A)%20t1%20ON%20matches.match_id%20%3D%20t1.match_id%0A%0A%0AWHERE%20TRUE%0AAND%20teams.team_id%20!%3D%200%0A--AND%20matches.start_time%20%3E%3D%201483218000%0AAND%20matches.start_time%20%3E%3D%20extract(epoch%20from%20timestamp%20%272017-03-01T21%3A00%3A00.000Z%27)%0AAND%20matches.start_time%20%3C%3D%20extract(epoch%20from%20timestamp%20%272017-04-30T21%3A00%3A00.000Z%27)%0AORDER%20BY%20matches.match_id%20DESC%20NULLS%20LAST"

# %% [markdown]
# # Загружаем данные в формате json, парсим и сохраняем в Pandas
#
# Предварительно ссылку стоит открыть в браузере, иначе она не хочет грузиться (слишком большая?)

# %%
response = urllib2.urlopen(urlQuery)
jsonResponse = response.read()
dictData = json.loads(jsonResponse)
matches = pd.DataFrame.from_dict(dictData['rows'])

# %% [markdown]
# # Добавляем уникальный идентификатор matchId_accountId и дату

# %%
matches['id'] = matches['match_id'].astype('str') + "_" + matches['account_id'].astype('str')
print matches.shape
matches['datetime'] = matches["start_time"].apply(lambda x: datetime.datetime.fromtimestamp(x).strftime('%d.%m.%Y %H:%M:%S'))
# Out:
# (5188, 68)

# %% [markdown]
# # Список переменных

# %%
list(matches)
# Out:
# [u'account_id',
#  u'assists',
#  u'attack_type',
#  u'buyback_log',
#  u'camps_stacked',
#  u'cluster',
#  u'creeps_stacked',
#  u'deaths',
#  u'denies',
#  u'dire',
#  u'duration',
#  u'first_blood_time',
#  u'gold_per_min',
#  u'gold_spent',
#  u'hero_damage',
#  u'hero_healing',
#  u'hero_id',
#  u'kills',
#  u'kills_log',
#  u'last_hits',
#  u'leagueid',
#  u'leaguename',
#  u'level',
#  u'localized_name',
#  u'match_id',
#  u'obs_log',
#  u'ping_log',
#  u'player_slot',
#  u'primary_attr',
#  u'purchase_log',
#  u'radiant',
#  u'role_log',
#  u'runes_log',
#  u'sen_log',
#  u'start_time',
#  u'stuns',
#  u't_experience_cnt_10',
#  u't_experience_cnt_12',
#  u't_experience_cnt_15',
#  u't_experience_cnt_20',
#  u't_experience_cnt_25',
#  u't_experience_cnt_3',
#  u't_experience_cnt_30',
#  u't_experience_cnt_5',
#  u't_experience_cnt_8',
#  u't_gold_cnt_10',
#  u't_gold_cnt_12',
#  u't_gold_cnt_15',
#  u't_gold_cnt_20',
#  u't_gold_cnt_25',
#  u't_gold_cnt_3',
#  u't_gold_cnt_30',
#  u't_gold_cnt_5',
#  u't_gold_cnt_8',
#  u't_lasthits_cnt_10',
#  u't_lasthits_cnt_12',
#  u't_lasthits_cnt_15',
#  u't_lasthits_cnt_20',
#  u't_lasthits_cnt_25',
#  u't_lasthits_cnt_3',
#  u't_lasthits_cnt_30',
#  u't_lasthits_cnt_5',
#  u't_lasthits_cnt_8',
#  u'team_id',
#  u'tower_damage',
#  u'win',
#  u'xp_per_min',
#  'id',
#  'datetime']

# %%
matches.head()
# Out:
#    account_id  assists attack_type  \
# 0    94155156       18      Ranged
# 1   311360822       10      Ranged
# 2    26771994       12       Melee
# 3    41231571       14       Melee
# 4    19672354       12       Melee
#
#                                          buyback_log  camps_stacked  cluster  \
# 0                                                 []            2.0      135
# 1  [{u'slot': 1, u'type': u'buyback_log', u'playe...            1.0      135
# 2                                                 []            0.0      135
# 3                                                 []            0.0      135
# 4  [{u'slot': 4, u'type': u'buyback_log', u'playe...            3.0      135
#
#    creeps_stacked  deaths  denies   dire         ...           \
# 0             6.0       5       2  False         ...
# 1             2.0       4       1  False         ...
# 2             0.0       6       2  False         ...
# 3             0.0       7      25  False         ...
# 4             8.0       7       6  False         ...
#
#    t_lasthits_cnt_3  t_lasthits_cnt_30  t_lasthits_cnt_5  t_lasthits_cnt_8  \
# 0               2.0               33.0               4.0               5.0
# 1               5.0              232.0              12.0              23.0
# 2               0.0               48.0               0.0               2.0
# 3               4.0              154.0              14.0              28.0
# 4               7.0              175.0              20.0              45.0
#
#    team_id  tower_damage   win  xp_per_min                    id  \
# 0  2586976           366  True         454   3149572447_94155156
# 1  2586976         15885  True         617  3149572447_311360822
# 2  2586976            22  True         317   3149572447_26771994
# 3  2586976          1320  True         467   3149572447_41231571
# 4  2586976           293  True         629   3149572447_19672354
#
#               datetime
# 0  30.04.2017 22:09:06
# 1  30.04.2017 22:09:06
# 2  30.04.2017 22:09:06
# 3  30.04.2017 22:09:06
# 4  30.04.2017 22:09:06
#
# [5 rows x 69 columns]

# %%
matches.tail()
# Out:
#       account_id  assists attack_type buyback_log  camps_stacked  cluster  \
# 5183   127077041       11      Ranged          []            2.0      154
# 5184    89603649       18      Ranged          []            0.0      154
# 5185    21289303       13       Melee          []            0.0      154
# 5186   100471531       23       Melee          []            2.0      154
# 5187    85417034       21       Melee          []            0.0      154
#
#       creeps_stacked  deaths  denies   dire         ...           \
# 5183             6.0       7       7  False         ...
# 5184             0.0       7       1   True         ...
# 5185             0.0       1      19   True         ...
# 5186             4.0       6       2   True         ...
# 5187             0.0       5       0   True         ...
#
#       t_lasthits_cnt_3  t_lasthits_cnt_30  t_lasthits_cnt_5  t_lasthits_cnt_8  \
# 5183               1.0               59.0               4.0              10.0
# 5184               2.0               44.0               3.0               5.0
# 5185               6.0              316.0              22.0              44.0
# 5186               3.0              135.0               9.0              22.0
# 5187               1.0               47.0               1.0               5.0
#
#       team_id  tower_damage    win  xp_per_min                    id  \
# 5183  3659536           391  False         326  3031875960_127077041
# 5184  3326875           404   True         348   3031875960_89603649
# 5185  3326875          8937   True         603   3031875960_21289303
# 5186  3326875           649   True         600  3031875960_100471531
# 5187  3326875           410   True         415   3031875960_85417034
#
#                  datetime
# 5183  03.03.2017 13:01:35
# 5184  03.03.2017 13:01:35
# 5185  03.03.2017 13:01:35
# 5186  03.03.2017 13:01:35
# 5187  03.03.2017 13:01:35
#
# [5 rows x 69 columns]

# %% [markdown]
# # Parse Items Timing

# %%
t_item = dict()
itemList = [
            'blink',
            'power_treads',
            'ultimate_scepter',
            'phase_boots',
            'travel_boots',
            'blade_mail',
            'arcane_boots',
            'black_king_bar',
            'desolator',
            'magic_wand',
            'tranquil_boots',
            'invis_sword',
            'echo_sabre',
            'manta',
            'ring_of_aquila',
            'force_staff',
            'aether_lens',
            'wind_lace',
            'silver_edge',
            'hand_of_midas',
            'sphere',
            'boots',
            'hurricane_pike',
            'bottle'            
            ]
columnNames = ['id']

for item in itemList:
    columnNames.append("t_item_" + item)

items = pd.DataFrame(columns = columnNames)
    
for i in range(0, len(matches['purchase_log'])):
    
    purchaseList = matches['purchase_log'][i]     
    for item in itemList:
        columnName = "t_item_" + item
        t_item[columnName] = np.nan
        
    if purchaseList is not None:
        for purchase in purchaseList:
            for item in itemList:
                columnName = "t_item_" + item
                if purchase['key'] == item and purchase['time'] < 30*60:
                    t_item[columnName] = purchase['time']
                    unique_id = matches['match_id'][i].astype('str') + "_" + matches['account_id'][i].astype('str')
                    t_item['id'] = unique_id
        itemsRow = pd.DataFrame.from_dict(t_item, orient = 'index').transpose()
        items = items.append(itemsRow, ignore_index=True)           
    else: print "Line %s: Log does not exists" %i
# Out:
# Line 314: Log does not exists
# Line 315: Log does not exists
# Line 316: Log does not exists
# Line 317: Log does not exists
# Line 318: Log does not exists
# Line 319: Log does not exists
# Line 320: Log does not exists
# Line 321: Log does not exists
# Line 322: Log does not exists
# Line 323: Log does not exists
# Line 512: Log does not exists
# Line 513: Log does not exists
# Line 514: Log does not exists
# Line 515: Log does not exists
# Line 516: Log does not exists
# Line 517: Log does not exists
# Line 518: Log does not exists
# Line 519: Log does not exists
# Line 520: Log does not exists
# Line 521: Log does not exists
# Line 3916: Log does not exists
# Line 3917: Log does not exists
# Line 3918: Log does not exists
# Line 3919: Log does not exists
# Line 3920: Log does not exists
# Line 3921: Log does not exists
# Line 3922: Log does not exists
# Line 3923: Log does not exists
# Line 3924: Log does not exists
# Line 3925: Log does not exists

# %%
items.shape
# Out:
# (5158, 25)

# %%
matches = matches.merge(items, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (5158, 93)

# %% [markdown]
# 73 записи было удалено из таблицы в связи с отсутствием логов о покупках игроков.

# %% [markdown]
# # First Kill Timing (Время в секундах от старта первой пачки крипов)

# %%
for i in range(0, len(matches)):
    matches.loc[i, 't_first_kill'] = 0
    try:
        t_first_kill = matches['kills_log'][i][0]['time']
    except Exception:
        print "Line %s: Player has 0 kills" %i
    if t_first_kill is not None:
        matches.loc[i, 't_first_kill'] = t_first_kill
# Out:
# Line 18: Player has 0 kills
# Line 27: Player has 0 kills
# Line 35: Player has 0 kills
# Line 45: Player has 0 kills
# Line 49: Player has 0 kills
# Line 57: Player has 0 kills
# Line 75: Player has 0 kills
# Line 111: Player has 0 kills
# Line 145: Player has 0 kills
# Line 162: Player has 0 kills
# Line 172: Player has 0 kills
# Line 175: Player has 0 kills
# Line 176: Player has 0 kills
# Line 213: Player has 0 kills
# Line 221: Player has 0 kills
# Line 239: Player has 0 kills
# Line 240: Player has 0 kills
# Line 242: Player has 0 kills
# Line 253: Player has 0 kills
# Line 256: Player has 0 kills
# Line 257: Player has 0 kills
# Line 262: Player has 0 kills
# Line 313: Player has 0 kills
# Line 316: Player has 0 kills
# Line 318: Player has 0 kills
# Line 323: Player has 0 kills
# Line 324: Player has 0 kills
# Line 326: Player has 0 kills
# Line 328: Player has 0 kills
# Line 367: Player has 0 kills
# Line 383: Player has 0 kills
# Line 397: Player has 0 kills
# Line 409: Player has 0 kills
# Line 411: Player has 0 kills
# Line 413: Player has 0 kills
# Line 415: Player has 0 kills
# Line 416: Player has 0 kills
# Line 418: Player has 0 kills
# Line 429: Player has 0 kills
# Line 438: Player has 0 kills
# Line 442: Player has 0 kills
# Line 447: Player has 0 kills
# Line 448: Player has 0 kills
# Line 449: Player has 0 kills
# Line 483: Player has 0 kills
# Line 486: Player has 0 kills
# Line 497: Player has 0 kills
# Line 529: Player has 0 kills
# Line 531: Player has 0 kills
# Line 552: Player has 0 kills
# Line 581: Player has 0 kills
# Line 611: Player has 0 kills
# Line 613: Player has 0 kills
# Line 620: Player has 0 kills
# Line 623: Player has 0 kills
# Line 624: Player has 0 kills
# Line 658: Player has 0 kills
# Line 703: Player has 0 kills
# Line 754: Player has 0 kills
# Line 756: Player has 0 kills
# Line 770: Player has 0 kills
# Line 783: Player has 0 kills
# Line 797: Player has 0 kills
# Line 808: Player has 0 kills
# Line 811: Player has 0 kills
# Line 813: Player has 0 kills
# Line 849: Player has 0 kills
# Line 850: Player has 0 kills
# Line 851: Player has 0 kills
# Line 852: Player has 0 kills
# Line 864: Player has 0 kills
# Line 884: Player has 0 kills
# Line 887: Player has 0 kills
# Line 899: Player has 0 kills
# Line 901: Player has 0 kills
# Line 907: Player has 0 kills
# Line 914: Player has 0 kills
# Line 923: Player has 0 kills
# Line 924: Player has 0 kills
# Line 925: Player has 0 kills
# Line 929: Player has 0 kills
# Line 934: Player has 0 kills
# Line 955: Player has 0 kills
# Line 980: Player has 0 kills
# Line 994: Player has 0 kills
# Line 1016: Player has 0 kills
# Line 1068: Player has 0 kills
# Line 1070: Player has 0 kills
# Line 1089: Player has 0 kills
# Line 1092: Player has 0 kills
# Line 1103: Player has 0 kills
# Line 1110: Player has 0 kills
# Line 1137: Player has 0 kills
# Line 1180: Player has 0 kills
# Line 1197: Player has 0 kills
# Line 1210: Player has 0 kills
# Line 1211: Player has 0 kills
# Line 1225: Player has 0 kills
# Line 1232: Player has 0 kills
# Line 1233: Player has 0 kills
# Line 1234: Player has 0 kills
# Line 1281: Player has 0 kills
# Line 1282: Player has 0 kills
# Line 1294: Player has 0 kills
# Line 1303: Player has 0 kills
# Line 1311: Player has 0 kills
# Line 1317: Player has 0 kills
# Line 1323: Player has 0 kills
# Line 1324: Player has 0 kills
# Line 1340: Player has 0 kills
# Line 1355: Player has 0 kills
# Line 1373: Player has 0 kills
# Line 1416: Player has 0 kills
# Line 1431: Player has 0 kills
# Line 1448: Player has 0 kills
# Line 1498: Player has 0 kills
# Line 1508: Player has 0 kills
# Line 1538: Player has 0 kills
# Line 1551: Player has 0 kills
# Line 1560: Player has 0 kills
# Line 1573: Player has 0 kills
# Line 1575: Player has 0 kills
# Line 1580: Player has 0 kills
# Line 1582: Player has 0 kills
# Line 1610: Player has 0 kills
# Line 1612: Player has 0 kills
# Line 1637: Player has 0 kills
# Line 1646: Player has 0 kills
# Line 1647: Player has 0 kills
# Line 1649: Player has 0 kills
# Line 1650: Player has 0 kills
# Line 1662: Player has 0 kills
# Line 1664: Player has 0 kills
# Line 1666: Player has 0 kills
# Line 1668: Player has 0 kills
# Line 1669: Player has 0 kills
# Line 1677: Player has 0 kills
# Line 1719: Player has 0 kills
# Line 1737: Player has 0 kills
# Line 1754: Player has 0 kills
# Line 1783: Player has 0 kills
# Line 1788: Player has 0 kills
# Line 1815: Player has 0 kills
# Line 1832: Player has 0 kills
# Line 1841: Player has 0 kills
# Line 1868: Player has 0 kills
# Line 1897: Player has 0 kills
# Line 1913: Player has 0 kills
# Line 1931: Player has 0 kills
# Line 1933: Player has 0 kills
# Line 1934: Player has 0 kills
# Line 1935: Player has 0 kills
# Line 1936: Player has 0 kills
# Line 2041: Player has 0 kills
# Line 2048: Player has 0 kills
# Line 2081: Player has 0 kills
# Line 2086: Player has 0 kills
# Line 2087: Player has 0 kills
# Line 2089: Player has 0 kills
# Line 2090: Player has 0 kills
# Line 2101: Player has 0 kills
# Line 2108: Player has 0 kills
# Line 2123: Player has 0 kills
# Line 2137: Player has 0 kills
# Line 2138: Player has 0 kills
# Line 2139: Player has 0 kills
# Line 2141: Player has 0 kills
# Line 2169: Player has 0 kills
# Line 2179: Player has 0 kills
# Line 2191: Player has 0 kills
# Line 2198: Player has 0 kills
# Line 2201: Player has 0 kills
# Line 2204: Player has 0 kills
# Line 2213: Player has 0 kills
# Line 2224: Player has 0 kills
# Line 2241: Player has 0 kills
# Line 2244: Player has 0 kills
# Line 2257: Player has 0 kills
# Line 2268: Player has 0 kills
# Line 2301: Player has 0 kills
# Line 2305: Player has 0 kills
# Line 2310: Player has 0 kills
# Line 2312: Player has 0 kills
# Line 2320: Player has 0 kills
# Line 2323: Player has 0 kills
# Line 2325: Player has 0 kills
# Line 2328: Player has 0 kills
# Line 2340: Player has 0 kills
# Line 2353: Player has 0 kills
# Line 2357: Player has 0 kills
# Line 2360: Player has 0 kills
# Line 2412: Player has 0 kills
# Line 2433: Player has 0 kills
# Line 2448: Player has 0 kills
# Line 2449: Player has 0 kills
# Line 2477: Player has 0 kills
# Line 2479: Player has 0 kills
# Line 2480: Player has 0 kills
# Line 2484: Player has 0 kills
# Line 2494: Player has 0 kills
# Line 2521: Player has 0 kills
# Line 2544: Player has 0 kills
# Line 2550: Player has 0 kills
# Line 2557: Player has 0 kills
# Line 2568: Player has 0 kills
# Line 2569: Player has 0 kills
# Line 2589: Player has 0 kills
# Line 2592: Player has 0 kills
# Line 2607: Player has 0 kills
# Line 2617: Player has 0 kills
# Line 2666: Player has 0 kills
# Line 2677: Player has 0 kills
# Line 2681: Player has 0 kills
# Line 2703: Player has 0 kills
# Line 2712: Player has 0 kills
# Line 2714: Player has 0 kills
# Line 2717: Player has 0 kills
# Line 2722: Player has 0 kills
# Line 2730: Player has 0 kills
# Line 2731: Player has 0 kills
# Line 2740: Player has 0 kills
# Line 2770: Player has 0 kills
# Line 2771: Player has 0 kills
# Line 2793: Player has 0 kills
# Line 2801: Player has 0 kills
# Line 2802: Player has 0 kills
# Line 2803: Player has 0 kills
# Line 2865: Player has 0 kills
# Line 2889: Player has 0 kills
# Line 2948: Player has 0 kills
# Line 2953: Player has 0 kills
# Line 2983: Player has 0 kills
# Line 2985: Player has 0 kills
# Line 2987: Player has 0 kills
# Line 3057: Player has 0 kills
# Line 3058: Player has 0 kills
# Line 3075: Player has 0 kills
# Line 3090: Player has 0 kills
# Line 3099: Player has 0 kills
# Line 3110: Player has 0 kills
# Line 3113: Player has 0 kills
# Line 3117: Player has 0 kills
# Line 3128: Player has 0 kills
# Line 3189: Player has 0 kills
# Line 3197: Player has 0 kills
# Line 3201: Player has 0 kills
# Line 3219: Player has 0 kills
# Line 3228: Player has 0 kills
# Line 3229: Player has 0 kills
# Line 3232: Player has 0 kills
# Line 3265: Player has 0 kills
# Line 3282: Player has 0 kills
# Line 3289: Player has 0 kills
# Line 3291: Player has 0 kills
# Line 3319: Player has 0 kills
# Line 3321: Player has 0 kills
# Line 3322: Player has 0 kills
# Line 3330: Player has 0 kills
# Line 3339: Player has 0 kills
# Line 3351: Player has 0 kills
# Line 3353: Player has 0 kills
# Line 3388: Player has 0 kills
# Line 3413: Player has 0 kills
# Line 3427: Player has 0 kills
# Line 3430: Player has 0 kills
# Line 3432: Player has 0 kills
# Line 3452: Player has 0 kills
# Line 3477: Player has 0 kills
# Line 3480: Player has 0 kills
# Line 3509: Player has 0 kills
# Line 3513: Player has 0 kills
# Line 3576: Player has 0 kills
# Line 3603: Player has 0 kills
# Line 3622: Player has 0 kills
# Line 3633: Player has 0 kills
# Line 3638: Player has 0 kills
# Line 3649: Player has 0 kills
# Line 3663: Player has 0 kills
# Line 3667: Player has 0 kills
# Line 3681: Player has 0 kills
# Line 3683: Player has 0 kills
# Line 3696: Player has 0 kills
# Line 3710: Player has 0 kills
# Line 3712: Player has 0 kills
# Line 3758: Player has 0 kills
# Line 3766: Player has 0 kills
# Line 3817: Player has 0 kills
# Line 3838: Player has 0 kills
# Line 3853: Player has 0 kills
# Line 3858: Player has 0 kills
# Line 3875: Player has 0 kills
# Line 3883: Player has 0 kills
# Line 3894: Player has 0 kills
# Line 3906: Player has 0 kills
# Line 3912: Player has 0 kills
# Line 3917: Player has 0 kills
# Line 3922: Player has 0 kills
# Line 3923: Player has 0 kills
# Line 3934: Player has 0 kills
# Line 3936: Player has 0 kills
# Line 3950: Player has 0 kills
# Line 3952: Player has 0 kills
# Line 3977: Player has 0 kills
# Line 3978: Player has 0 kills
# Line 3979: Player has 0 kills
# Line 3982: Player has 0 kills
# Line 3984: Player has 0 kills
# Line 3986: Player has 0 kills
# Line 3993: Player has 0 kills
# Line 3995: Player has 0 kills
# Line 4003: Player has 0 kills
# Line 4011: Player has 0 kills
# Line 4013: Player has 0 kills
# Line 4021: Player has 0 kills
# Line 4029: Player has 0 kills
# Line 4030: Player has 0 kills
# Line 4031: Player has 0 kills
# Line 4066: Player has 0 kills
# Line 4087: Player has 0 kills
# Line 4142: Player has 0 kills
# Line 4145: Player has 0 kills
# Line 4147: Player has 0 kills
# Line 4154: Player has 0 kills
# Line 4158: Player has 0 kills
# Line 4161: Player has 0 kills
# Line 4168: Player has 0 kills
# Line 4191: Player has 0 kills
# Line 4198: Player has 0 kills
# Line 4206: Player has 0 kills
# Line 4208: Player has 0 kills
# Line 4209: Player has 0 kills
# Line 4224: Player has 0 kills
# Line 4225: Player has 0 kills
# Line 4231: Player has 0 kills
# Line 4238: Player has 0 kills
# Line 4241: Player has 0 kills
# Line 4243: Player has 0 kills
# Line 4246: Player has 0 kills
# Line 4252: Player has 0 kills
# Line 4258: Player has 0 kills
# Line 4261: Player has 0 kills
# Line 4262: Player has 0 kills
# Line 4263: Player has 0 kills
# Line 4271: Player has 0 kills
# Line 4288: Player has 0 kills
# Line 4301: Player has 0 kills
# Line 4302: Player has 0 kills
# Line 4313: Player has 0 kills
# Line 4317: Player has 0 kills
# Line 4350: Player has 0 kills
# Line 4351: Player has 0 kills
# Line 4365: Player has 0 kills
# Line 4368: Player has 0 kills
# Line 4379: Player has 0 kills
# Line 4382: Player has 0 kills
# Line 4383: Player has 0 kills
# Line 4388: Player has 0 kills
# Line 4397: Player has 0 kills
# Line 4435: Player has 0 kills
# Line 4451: Player has 0 kills
# Line 4469: Player has 0 kills
# Line 4482: Player has 0 kills
# Line 4502: Player has 0 kills
# Line 4512: Player has 0 kills
# Line 4515: Player has 0 kills
# Line 4517: Player has 0 kills
# Line 4518: Player has 0 kills
# Line 4519: Player has 0 kills
# Line 4521: Player has 0 kills
# Line 4542: Player has 0 kills
# Line 4567: Player has 0 kills
# Line 4576: Player has 0 kills
# Line 4580: Player has 0 kills
# Line 4601: Player has 0 kills
# Line 4611: Player has 0 kills
# Line 4612: Player has 0 kills
# Line 4615: Player has 0 kills
# Line 4653: Player has 0 kills
# Line 4671: Player has 0 kills
# Line 4675: Player has 0 kills
# Line 4708: Player has 0 kills
# Line 4719: Player has 0 kills
# Line 4720: Player has 0 kills
# Line 4733: Player has 0 kills
# Line 4758: Player has 0 kills
# Line 4764: Player has 0 kills
# Line 4777: Player has 0 kills
# Line 4803: Player has 0 kills
# Line 4807: Player has 0 kills
# Line 4826: Player has 0 kills
# Line 4827: Player has 0 kills
# Line 4828: Player has 0 kills
# Line 4829: Player has 0 kills
# Line 4830: Player has 0 kills
# Line 4835: Player has 0 kills
# Line 4844: Player has 0 kills
# Line 4847: Player has 0 kills
# Line 4849: Player has 0 kills
# Line 4851: Player has 0 kills
# Line 4853: Player has 0 kills
# Line 4864: Player has 0 kills
# Line 4867: Player has 0 kills
# Line 4869: Player has 0 kills
# Line 4908: Player has 0 kills
# Line 4917: Player has 0 kills
# Line 4918: Player has 0 kills
# Line 4930: Player has 0 kills
# Line 4933: Player has 0 kills
# Line 4943: Player has 0 kills
# Line 4954: Player has 0 kills
# Line 4971: Player has 0 kills
# Line 4977: Player has 0 kills
# Line 5000: Player has 0 kills
# Line 5002: Player has 0 kills
# Line 5008: Player has 0 kills
# Line 5011: Player has 0 kills
# Line 5022: Player has 0 kills
# Line 5039: Player has 0 kills
# Line 5078: Player has 0 kills
# Line 5089: Player has 0 kills
# Line 5095: Player has 0 kills
# Line 5096: Player has 0 kills
# Line 5098: Player has 0 kills
# Line 5099: Player has 0 kills
# Line 5100: Player has 0 kills
# Line 5110: Player has 0 kills
# Line 5123: Player has 0 kills

# %%
matches.shape
# Out:
# (5158, 94)

# %%
matches['t_first_kill'].plot(kind = 'hist')

# %% [markdown]
# # sen_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
sen_cnt = {
                'id':0,
                't_sen_cnt_3':0,
                't_sen_cnt_5':0,
                't_sen_cnt_8':0,
                't_sen_cnt_10':0,
                't_sen_cnt_12':0,
                't_sen_cnt_15':0,
                't_sen_cnt_20':0,
                't_sen_cnt_25':0,
                't_sen_cnt_30':0       
                }

sen = pd.DataFrame(columns = [key for key, value in sen_cnt.items()])

for i in range(0, len(matches['sen_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    sen_cnt = {
                'id':0,
                't_sen_cnt_3':0,
                't_sen_cnt_5':0,
                't_sen_cnt_8':0,
                't_sen_cnt_10':0,
                't_sen_cnt_12':0,
                't_sen_cnt_15':0,
                't_sen_cnt_20':0,
                't_sen_cnt_25':0,
                't_sen_cnt_30':0,
                't_sen_rpm_3':0,
                't_sen_rpm_5':0,
                't_sen_rpm_8':0,
                't_sen_rpm_10':0,
                't_sen_rpm_12':0,
                't_sen_rpm_15':0,
                't_sen_rpm_20':0,
                't_sen_rpm_25':0,
                't_sen_rpm_30':0    
                }
    try: 
        if matches['sen_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['sen_log'][i])):
                for timeStamp in timeStamps:
                    if matches['sen_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_sen_cnt_" + timeStamp
                        varName_rpm = "t_sen_rpm_" + timeStamp
                        sen_cnt[varName_cnt] += 1
                        sen_cnt[varName_rpm] += 1 / float(timeStamp)
            sen_cnt['id'] = matches['id'][i]
            senRow = pd.DataFrame.from_dict(sen_cnt, orient = 'index').transpose()
            sen = sen.append(senRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed

# %%
matches = matches.merge(sen, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (5158, 112)

# %% [markdown]
# # Возникают новые записи в таблице, хотя используется inner join. С чем это может быть связано?

# %% [markdown]
# # obs_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
obs_cnt = {
                'id':0,
                't_obs_cnt_3':0,
                't_obs_cnt_5':0,
                't_obs_cnt_8':0,
                't_obs_cnt_10':0,
                't_obs_cnt_12':0,
                't_obs_cnt_15':0,
                't_obs_cnt_20':0,
                't_obs_cnt_25':0,
                't_obs_cnt_30':0       
                }

obs = pd.DataFrame(columns = [key for key, value in obs_cnt.items()])

for i in range(0, len(matches['obs_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    obs_cnt = {
                'id':0,
                't_obs_cnt_3':0,
                't_obs_cnt_5':0,
                't_obs_cnt_8':0,
                't_obs_cnt_10':0,
                't_obs_cnt_12':0,
                't_obs_cnt_15':0,
                't_obs_cnt_20':0,
                't_obs_cnt_25':0,
                't_obs_cnt_30':0,
                't_obs_rpm_3':0,
                't_obs_rpm_5':0,
                't_obs_rpm_8':0,
                't_obs_rpm_10':0,
                't_obs_rpm_12':0,
                't_obs_rpm_15':0,
                't_obs_rpm_20':0,
                't_obs_rpm_25':0,
                't_obs_rpm_30':0    
                }
    try: 
        if matches['obs_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['obs_log'][i])):
                for timeStamp in timeStamps:
                    if matches['obs_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_obs_cnt_" + timeStamp
                        varName_rpm = "t_obs_rpm_" + timeStamp
                        obs_cnt[varName_cnt] += 1
                        obs_cnt[varName_rpm] += 1 / float(timeStamp)
            obs_cnt['id'] = matches['id'][i]
            obsRow = pd.DataFrame.from_dict(obs_cnt, orient = 'index').transpose()
            obs = obs.append(obsRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed

# %%
matches = matches.merge(obs, left_on='id', right_on='id', how='inner')
print matches.shape
# Out:
# (5158, 130)

# %% [markdown]
# # runes_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
runes_cnt = {
                'id':0,
                't_runes_cnt_3':0,
                't_runes_cnt_5':0,
                't_runes_cnt_8':0,
                't_runes_cnt_10':0,
                't_runes_cnt_12':0,
                't_runes_cnt_15':0,
                't_runes_cnt_20':0,
                't_runes_cnt_25':0,
                't_runes_cnt_30':0       
                }

runes = pd.DataFrame(columns = [key for key, value in runes_cnt.items()])

for i in range(0, len(matches['runes_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    runes_cnt = {
                'id':0,
                't_runes_cnt_3':0,
                't_runes_cnt_5':0,
                't_runes_cnt_8':0,
                't_runes_cnt_10':0,
                't_runes_cnt_12':0,
                't_runes_cnt_15':0,
                't_runes_cnt_20':0,
                't_runes_cnt_25':0,
                't_runes_cnt_30':0,
                't_runes_rpm_3':0,
                't_runes_rpm_5':0,
                't_runes_rpm_8':0,
                't_runes_rpm_10':0,
                't_runes_rpm_12':0,
                't_runes_rpm_15':0,
                't_runes_rpm_20':0,
                't_runes_rpm_25':0,
                't_runes_rpm_30':0    
                }
    try:
        if matches['runes_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['runes_log'][i])):
                for timeStamp in timeStamps:
                    if matches['runes_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_runes_cnt_" + timeStamp
                        varName_rpm = "t_runes_rpm_" + timeStamp
                        runes_cnt[varName_cnt] += 1
                        runes_cnt[varName_rpm] += 1 / float(timeStamp)
            runes_cnt['id'] = matches['id'][i]
            runesRow = pd.DataFrame.from_dict(runes_cnt, orient = 'index').transpose()
            runes = runes.append(runesRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed

# %%
matches = matches.merge(runes, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (5158, 148)

# %% [markdown]
# # buyback_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
buyback_cnt = {
                'id':0,
                't_buyback_cnt_3':0,
                't_buyback_cnt_5':0,
                't_buyback_cnt_8':0,
                't_buyback_cnt_10':0,
                't_buyback_cnt_12':0,
                't_buyback_cnt_15':0,
                't_buyback_cnt_20':0,
                't_buyback_cnt_25':0,
                't_buyback_cnt_30':0       
                }

buyback = pd.DataFrame(columns = [key for key, value in buyback_cnt.items()])

for i in range(0, len(matches['buyback_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    buyback_cnt = {
                'id':0,
                't_buyback_cnt_3':0,
                't_buyback_cnt_5':0,
                't_buyback_cnt_8':0,
                't_buyback_cnt_10':0,
                't_buyback_cnt_12':0,
                't_buyback_cnt_15':0,
                't_buyback_cnt_20':0,
                't_buyback_cnt_25':0,
                't_buyback_cnt_30':0,
                't_buyback_rpm_3':0,
                't_buyback_rpm_5':0,
                't_buyback_rpm_8':0,
                't_buyback_rpm_10':0,
                't_buyback_rpm_12':0,
                't_buyback_rpm_15':0,
                't_buyback_rpm_20':0,
                't_buyback_rpm_25':0,
                't_buyback_rpm_30':0    
                }
    try: 
        if matches['buyback_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['buyback_log'][i])):
                for timeStamp in timeStamps:
                    if matches['buyback_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_buyback_cnt_" + timeStamp
                        varName_rpm = "t_buyback_rpm_" + timeStamp
                        buyback_cnt[varName_cnt] += 1
                        buyback_cnt[varName_rpm] += 1 / float(timeStamp)
            buyback_cnt['id'] = matches['id'][i]
            buybackRow = pd.DataFrame.from_dict(buyback_cnt, orient = 'index').transpose()
            buyback = buyback.append(buybackRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed

# %%
matches = matches.merge(buyback, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (5158, 166)

# %%
buyback.shape
# Out:
# (5158, 19)

# %% [markdown]
# # Hero statistics

# %%
urlHeroes = "https://api.opendota.com/api/heroStats"

# %%
response = urllib2.urlopen(urlHeroes)
jsonResponse = response.read()
dictData = json.loads(jsonResponse)

# %%
heroesList = list()
heroAttr = [
            'id',
            'localized_name', 
            'attack_type',
            'pro_ban', 
            'pro_pick', 
            'pro_win', 
            'primary_attr', 
            'roles'
            ]
heroRolesList = [
                'Carry',
                'Disabler',
                'Initiator',
                'Jungler',
                'Support',
                'Durable',
                'Nuker',
                'Escape',
                'Pusher'
                ]

for heroId in range(0, len(dictData) - 1):    
    heroRaw = dict()
    
    for heroRole in heroRolesList:
        heroRaw[heroRole] = 0
    for key, value in dictData[heroId].iteritems():
        if key in heroAttr:
            heroRaw[key] = dictData[heroId][key]
            if key == 'roles':
                for heroRole in dictData[heroId][key]:
                    heroRaw[heroRole] = 1
    del heroRaw['roles']                
    heroesList.append(heroRaw)

# %%
heroes = pd.DataFrame(heroesList)
print heroes.shape
heroes.head()
# Out:
# (112, 16)
#    Carry  Disabler  Durable  Escape  Initiator  Jungler  Nuker  Pusher  \
# 0      1         0        0       1          0        0      1       0
# 1      0         1        1       0          1        1      0       0
# 2      0         1        1       0          0        0      1       0
# 3      1         1        0       0          1        1      1       0
# 4      0         1        0       0          0        1      1       0
#
#    Support attack_type  id  localized_name primary_attr  pro_ban  pro_pick  \
# 0        0       Melee   1       Anti-Mage          agi     51.0      62.0
# 1        0       Melee   2             Axe          str    192.0     174.0
# 2        1      Ranged   3            Bane          int      1.0      17.0
# 3        0       Melee   4     Bloodseeker          agi      7.0      12.0
# 4        1      Ranged   5  Crystal Maiden          int    107.0     524.0
#
#    pro_win
# 0     33.0
# 1     94.0
# 2     12.0
# 3      6.0
# 4    302.0

# %% [markdown]
# # Возможно косяк здесь, потому что есть по 4 записи на команду, а не 5

# %%
matches.groupby(['team_id', 'match_id'], as_index=False).count()
# Out:
#       team_id    match_id  account_id  assists  attack_type  buyback_log  \
# 0           3  3032935500           4        4            4            4
# 1           3  3033038349           4        4            4            4
# 2           3  3033099678           4        4            4            4
# 3           3  3033148738           4        4            4            4
# 4           3  3049748374           4        4            4            4
# 5           3  3051959931           4        4            4            4
# 6           3  3052019206           4        4            4            4
# 7           3  3053852703           4        4            4            4
# 8           3  3053886651           4        4            4            4
# 9           5  3047642996           5        5            5            5
# 10          5  3047746830           5        5            5            5
# 11          5  3048200698           5        5            5            5
# 12          5  3048346411           5        5            5            5
# 13          5  3049909705           5        5            5            5
# 14          5  3050090468           5        5            5            5
# 15          5  3050285208           5        5            5            5
# 16          5  3050580079           5        5            5            5
# 17          5  3051075730           5        5            5            5
# 18          5  3052224558           5        5            5            5
# 19          5  3052273647           5        5            5            5
# 20          5  3052338284           5        5            5            5
# 21          5  3052573239           5        5            5            5
# 22          5  3052656122           5        5            5            5
# 23          5  3052759824           5        5            5            5
# 24          5  3054282641           5        5            5            5
# 25          5  3054390158           5        5            5            5
# 26          5  3054488401           5        5            5            5
# 27          5  3056374006           5        5            5            5
# 28          5  3056458422           5        5            5            5
# 29          5  3062585246           5        5            5            5
# ...       ...         ...         ...      ...          ...          ...
# 1204  4253054  3091214026           5        5            5            5
# 1205  4253054  3102838959           5        5            5            5
# 1206  4253054  3102913143           5        5            5            5
# 1207  4253054  3105711723           5        5            5            5
# 1208  4253054  3105842270           5        5            5            5
# 1209  4253054  3107622917           5        5            5            5
# 1210  4253054  3107779938           5        5            5            5
# 1211  4253054  3108133533           5        5            5            5
# 1212  4253054  3108280015           5        5            5            5
# 1213  4253054  3113604473           5        5            5            5
# 1214  4253054  3113809516           5        5            5            5
# 1215  4253054  3115059536           5        5            5            5
# 1216  4253054  3115134394           5        5            5            5
# 1217  4253054  3115439923           5        5            5            5
# 1218  4253054  3115513870           5        5            5            5
# 1219  4253054  3115620923           5        5            5            5
# 1220  4253054  3137048517           5        5            5            5
# 1221  4253054  3137133270           5        5            5            5
# 1222  4253054  3137212042           5        5            5            5
# 1223  4253054  3137652123           5        5            5            5
# 1224  4253054  3137764244           5        5            5            5
# 1225  4253054  3137907375           5        5            5            5
# 1226  4253054  3138972122           5        5            5            5
# 1227  4253054  3139052266           5        5            5            5
# 1228  4253054  3139141584           5        5            5            5
# 1229  4253054  3139778329           5        5            5            5
# 1230  4253054  3139885713           5        5            5            5
# 1231  4253054  3144437316           5        5            5            5
# 1232  4253054  3144607791           5        5            5            5
# 1233  4253054  3144797892           5        5            5            5
#
#       camps_stacked  cluster  creeps_stacked  deaths       ...         \
# 0                 4        4               4       4       ...
# 1                 4        4               4       4       ...
# 2                 4        4               4       4       ...
# 3                 4        4               4       4       ...
# 4                 4        4               4       4       ...
# 5                 4        4               4       4       ...
# 6                 4        4               4       4       ...
# 7                 4        4               4       4       ...
# 8                 4        4               4       4       ...
# 9                 5        5               5       5       ...
# 10                5        5               5       5       ...
# 11                5        5               5       5       ...
# 12                5        5               5       5       ...
# 13                5        5               5       5       ...
# 14                5        5               5       5       ...
# 15                5        5               5       5       ...
# 16                5        5               5       5       ...
# 17                5        5               5       5       ...
# 18                5        5               5       5       ...
# 19                5        5               5       5       ...
# 20                5        5               5       5       ...
# 21                5        5               5       5       ...
# 22                5        5               5       5       ...
# 23                5        5               5       5       ...
# 24                5        5               5       5       ...
# 25                5        5               5       5       ...
# 26                5        5               5       5       ...
# 27                5        5               5       5       ...
# 28                5        5               5       5       ...
# 29                5        5               5       5       ...
# ...             ...      ...             ...     ...       ...
# 1204              5        5               5       5       ...
# 1205              5        5               5       5       ...
# 1206              5        5               5       5       ...
# 1207              5        5               5       5       ...
# 1208              5        5               5       5       ...
# 1209              5        5               5       5       ...
# 1210              5        5               5       5       ...
# 1211              5        5               5       5       ...
# 1212              5        5               5       5       ...
# 1213              5        5               5       5       ...
# 1214              5        5               5       5       ...
# 1215              5        5               5       5       ...
# 1216              5        5               5       5       ...
# 1217              5        5               5       5       ...
# 1218              5        5               5       5       ...
# 1219              5        5               5       5       ...
# 1220              5        5               5       5       ...
# 1221              5        5               5       5       ...
# 1222              5        5               5       5       ...
# 1223              5        5               5       5       ...
# 1224              5        5               5       5       ...
# 1225              5        5               5       5       ...
# 1226              5        5               5       5       ...
# 1227              5        5               5       5       ...
# 1228              5        5               5       5       ...
# 1229              5        5               5       5       ...
# 1230              5        5               5       5       ...
# 1231              5        5               5       5       ...
# 1232              5        5               5       5       ...
# 1233              5        5               5       5       ...
#
#       t_buyback_cnt_8  t_buyback_rpm_10  t_buyback_rpm_12  t_buyback_rpm_15  \
# 0                   4                 4                 4                 4
# 1                   4                 4                 4                 4
# 2                   4                 4                 4                 4
# 3                   4                 4                 4                 4
# 4                   4                 4                 4                 4
# 5                   4                 4                 4                 4
# 6                   4                 4                 4                 4
# 7                   4                 4                 4                 4
# 8                   4                 4                 4                 4
# 9                   5                 5                 5                 5
# 10                  5                 5                 5                 5
# 11                  5                 5                 5                 5
# 12                  5                 5                 5                 5
# 13                  5                 5                 5                 5
# 14                  5                 5                 5                 5
# 15                  5                 5                 5                 5
# 16                  5                 5                 5                 5
# 17                  5                 5                 5                 5
# 18                  5                 5                 5                 5
# 19                  5                 5                 5                 5
# 20                  5                 5                 5                 5
# 21                  5                 5                 5                 5
# 22                  5                 5                 5                 5
# 23                  5                 5                 5                 5
# 24                  5                 5                 5                 5
# 25                  5                 5                 5                 5
# 26                  5                 5                 5                 5
# 27                  5                 5                 5                 5
# 28                  5                 5                 5                 5
# 29                  5                 5                 5                 5
# ...               ...               ...               ...               ...
# 1204                5                 5                 5                 5
# 1205                5                 5                 5                 5
# 1206                5                 5                 5                 5
# 1207                5                 5                 5                 5
# 1208                5                 5                 5                 5
# 1209                5                 5                 5                 5
# 1210                5                 5                 5                 5
# 1211                5                 5                 5                 5
# 1212                5                 5                 5                 5
# 1213                5                 5                 5                 5
# 1214                5                 5                 5                 5
# 1215                5                 5                 5                 5
# 1216                5                 5                 5                 5
# 1217                5                 5                 5                 5
# 1218                5                 5                 5                 5
# 1219                5                 5                 5                 5
# 1220                5                 5                 5                 5
# 1221                5                 5                 5                 5
# 1222                5                 5                 5                 5
# 1223                5                 5                 5                 5
# 1224                5                 5                 5                 5
# 1225                5                 5                 5                 5
# 1226                5                 5                 5                 5
# 1227                5                 5                 5                 5
# 1228                5                 5                 5                 5
# 1229                5                 5                 5                 5
# 1230                5                 5                 5                 5
# 1231                5                 5                 5                 5
# 1232                5                 5                 5                 5
# 1233                5                 5                 5                 5
#
#       t_buyback_rpm_20  t_buyback_rpm_25  t_buyback_rpm_3  t_buyback_rpm_30  \
# 0                    4                 4                4                 4
# 1                    4                 4                4                 4
# 2                    4                 4                4                 4
# 3                    4                 4                4                 4
# 4                    4                 4                4                 4
# 5                    4                 4                4                 4
# 6                    4                 4                4                 4
# 7                    4                 4                4                 4
# 8                    4                 4                4                 4
# 9                    5                 5                5                 5
# 10                   5                 5                5                 5
# 11                   5                 5                5                 5
# 12                   5                 5                5                 5
# 13                   5                 5                5                 5
# 14                   5                 5                5                 5
# 15                   5                 5                5                 5
# 16                   5                 5                5                 5
# 17                   5                 5                5                 5
# 18                   5                 5                5                 5
# 19                   5                 5                5                 5
# 20                   5                 5                5                 5
# 21                   5                 5                5                 5
# 22                   5                 5                5                 5
# 23                   5                 5                5                 5
# 24                   5                 5                5                 5
# 25                   5                 5                5                 5
# 26                   5                 5                5                 5
# 27                   5                 5                5                 5
# 28                   5                 5                5                 5
# 29                   5                 5                5                 5
# ...                ...               ...              ...               ...
# 1204                 5                 5                5                 5
# 1205                 5                 5                5                 5
# 1206                 5                 5                5                 5
# 1207                 5                 5                5                 5
# 1208                 5                 5                5                 5
# 1209                 5                 5                5                 5
# 1210                 5                 5                5                 5
# 1211                 5                 5                5                 5
# 1212                 5                 5                5                 5
# 1213                 5                 5                5                 5
# 1214                 5                 5                5                 5
# 1215                 5                 5                5                 5
# 1216                 5                 5                5                 5
# 1217                 5                 5                5                 5
# 1218                 5                 5                5                 5
# 1219                 5                 5                5                 5
# 1220                 5                 5                5                 5
# 1221                 5                 5                5                 5
# 1222                 5                 5                5                 5
# 1223                 5                 5                5                 5
# 1224                 5                 5                5                 5
# 1225                 5                 5                5                 5
# 1226                 5                 5                5                 5
# 1227                 5                 5                5                 5
# 1228                 5                 5                5                 5
# 1229                 5                 5                5                 5
# 1230                 5                 5                5                 5
# 1231                 5                 5                5                 5
# 1232                 5                 5                5                 5
# 1233                 5                 5                5                 5
#
#       t_buyback_rpm_5  t_buyback_rpm_8
# 0                   4                4
# 1                   4                4
# 2                   4                4
# 3                   4                4
# 4                   4                4
# 5                   4                4
# 6                   4                4
# 7                   4                4
# 8                   4                4
# 9                   5                5
# 10                  5                5
# 11                  5                5
# 12                  5                5
# 13                  5                5
# 14                  5                5
# 15                  5                5
# 16                  5                5
# 17                  5                5
# 18                  5                5
# 19                  5                5
# 20                  5                5
# 21                  5                5
# 22                  5                5
# 23                  5                5
# 24                  5                5
# 25                  5                5
# 26                  5                5
# 27                  5                5
# 28                  5                5
# 29                  5                5
# ...               ...              ...
# 1204                5                5
# 1205                5                5
# 1206                5                5
# 1207                5                5
# 1208                5                5
# 1209                5                5
# 1210                5                5
# 1211                5                5
# 1212                5                5
# 1213                5                5
# 1214                5                5
# 1215                5                5
# 1216                5                5
# 1217                5                5
# 1218                5                5
# 1219                5                5
# 1220                5                5
# 1221                5                5
# 1222                5                5
# 1223                5                5
# 1224                5                5
# 1225                5                5
# 1226                5                5
# 1227                5                5
# 1228                5                5
# 1229                5                5
# 1230                5                5
# 1231                5                5
# 1232                5                5
# 1233                5                5
#
# [1234 rows x 166 columns]

# %%
matches= matches.merge(heroes, left_on = 'hero_id', right_on = 'id', how = 'inner')
matches.shape
# Out:
# (5010, 182)

# %% [markdown]
# # EXP_RPM

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
var = 'experience'
varTemplate = 't_' + var + '_'
for timeStamp in timeStamps:
    varName_cnt = varTemplate + 'cnt_' + timeStamp
    varName_rpm = varTemplate + 'rpm_' + timeStamp
    matches[varName_rpm] = matches[varName_cnt] / float(timeStamp)

# %% [markdown]
# # GOLD_RPM

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
var = 'gold'
varTemplate = 't_' + var + '_'
for timeStamp in timeStamps:
    varName_cnt = varTemplate + 'cnt_' + timeStamp
    varName_rpm = varTemplate + 'rpm_' + timeStamp
    matches[varName_rpm] = matches[varName_cnt] / float(timeStamp)

# %% [markdown]
# # LASTHITS_RPM

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
var = 'lasthits'
varTemplate = 't_' + var + '_'
for timeStamp in timeStamps:
    varName_cnt = varTemplate + 'cnt_' + timeStamp
    varName_rpm = varTemplate + 'rpm_' + timeStamp
    matches[varName_rpm] = matches[varName_cnt] / float(timeStamp)

# %%
for col in list(matches):
    print col
# Out:
# account_id
# assists
# attack_type_x
# buyback_log
# camps_stacked
# cluster
# creeps_stacked
# deaths
# denies
# dire
# duration
# first_blood_time
# gold_per_min
# gold_spent
# hero_damage
# hero_healing
# hero_id
# kills
# kills_log
# last_hits
# leagueid
# leaguename
# level
# localized_name_x
# match_id
# obs_log
# ping_log
# player_slot
# primary_attr_x
# purchase_log
# radiant
# role_log
# runes_log
# sen_log
# start_time
# stuns
# t_experience_cnt_10
# t_experience_cnt_12
# t_experience_cnt_15
# t_experience_cnt_20
# t_experience_cnt_25
# t_experience_cnt_3
# t_experience_cnt_30
# t_experience_cnt_5
# t_experience_cnt_8
# t_gold_cnt_10
# t_gold_cnt_12
# t_gold_cnt_15
# t_gold_cnt_20
# t_gold_cnt_25
# t_gold_cnt_3
# t_gold_cnt_30
# t_gold_cnt_5
# t_gold_cnt_8
# t_lasthits_cnt_10
# t_lasthits_cnt_12
# t_lasthits_cnt_15
# t_lasthits_cnt_20
# t_lasthits_cnt_25
# t_lasthits_cnt_3
# t_lasthits_cnt_30
# t_lasthits_cnt_5
# t_lasthits_cnt_8
# team_id
# tower_damage
# win
# xp_per_min
# id_x
# datetime
# t_item_aether_lens
# t_item_arcane_boots
# t_item_black_king_bar
# t_item_blade_mail
# t_item_blink
# t_item_boots
# t_item_bottle
# t_item_desolator
# t_item_echo_sabre
# t_item_force_staff
# t_item_hand_of_midas
# t_item_hurricane_pike
# t_item_invis_sword
# t_item_magic_wand
# t_item_manta
# t_item_phase_boots
# t_item_power_treads
# t_item_ring_of_aquila
# t_item_silver_edge
# t_item_sphere
# t_item_tranquil_boots
# t_item_travel_boots
# t_item_ultimate_scepter
# t_item_wind_lace
# t_first_kill
# t_sen_cnt_10
# t_sen_cnt_12
# t_sen_cnt_15
# t_sen_cnt_20
# t_sen_cnt_25
# t_sen_cnt_3
# t_sen_cnt_30
# t_sen_cnt_5
# t_sen_cnt_8
# t_sen_rpm_10
# t_sen_rpm_12
# t_sen_rpm_15
# t_sen_rpm_20
# t_sen_rpm_25
# t_sen_rpm_3
# t_sen_rpm_30
# t_sen_rpm_5
# t_sen_rpm_8
# t_obs_cnt_10
# t_obs_cnt_12
# t_obs_cnt_15
# t_obs_cnt_20
# t_obs_cnt_25
# t_obs_cnt_3
# t_obs_cnt_30
# t_obs_cnt_5
# t_obs_cnt_8
# t_obs_rpm_10
# t_obs_rpm_12
# t_obs_rpm_15
# t_obs_rpm_20
# t_obs_rpm_25
# t_obs_rpm_3
# t_obs_rpm_30
# t_obs_rpm_5
# t_obs_rpm_8
# t_runes_cnt_10
# t_runes_cnt_12
# t_runes_cnt_15
# t_runes_cnt_20
# t_runes_cnt_25
# t_runes_cnt_3
# t_runes_cnt_30
# t_runes_cnt_5
# t_runes_cnt_8
# t_runes_rpm_10
# t_runes_rpm_12
# t_runes_rpm_15
# t_runes_rpm_20
# t_runes_rpm_25
# t_runes_rpm_3
# t_runes_rpm_30
# t_runes_rpm_5
# t_runes_rpm_8
# t_buyback_cnt_10
# t_buyback_cnt_12
# t_buyback_cnt_15
# t_buyback_cnt_20
# t_buyback_cnt_25
# t_buyback_cnt_3
# t_buyback_cnt_30
# t_buyback_cnt_5
# t_buyback_cnt_8
# t_buyback_rpm_10
# t_buyback_rpm_12
# t_buyback_rpm_15
# t_buyback_rpm_20
# t_buyback_rpm_25
# t_buyback_rpm_3
# t_buyback_rpm_30
# t_buyback_rpm_5
# t_buyback_rpm_8
# Carry
# Disabler
# Durable
# Escape
# Initiator
# Jungler
# Nuker
# Pusher
# Support
# attack_type_y
# id_y
# localized_name_y
# primary_attr_y
# pro_ban
# pro_pick
# pro_win
# t_experience_rpm_3
# t_experience_rpm_5
# t_experience_rpm_8
# t_experience_rpm_10
# t_experience_rpm_12
# t_experience_rpm_15
# t_experience_rpm_20
# t_experience_rpm_25
# t_experience_rpm_30
# t_gold_rpm_3
# t_gold_rpm_5
# t_gold_rpm_8
# t_gold_rpm_10
# t_gold_rpm_12
# t_gold_rpm_15
# t_gold_rpm_20
# t_gold_rpm_25
# t_gold_rpm_30
# t_lasthits_rpm_3
# t_lasthits_rpm_5
# t_lasthits_rpm_8
# t_lasthits_rpm_10
# t_lasthits_rpm_12
# t_lasthits_rpm_15
# t_lasthits_rpm_20
# t_lasthits_rpm_25
# t_lasthits_rpm_30

# %% [markdown]
# # Заметка: после join появляются id_x и id_y - айдишники правых и левых таблиц

# %%
print matches['id_x'].unique().size
# Out:
# 5010

# %%
print matches['id_y'].unique().size
# Out:
# 111

# %% [markdown]
# # Используем id_x в качестве уникального id.
# Аналог SQL select distinct id_x from matches (Удаляем дубликаты)

# %%
matches.drop_duplicates(subset = 'id_x', inplace = True)

# %%
matches.shape
# Out:
# (5010, 209)

# %%
matchesWithoutLogs = matches.drop(labels = ['buyback_log', 'kills_log', 'obs_log', 'ping_log', 'purchase_log', 'role_log', 'runes_log', 'sen_log'], axis = 1)

# %% [markdown]
# # Добавление ролей игроков

# %%
playersRoles = pd.read_csv('Account_Role.csv', sep = ';')

# %%
playersRoles.drop('player_id', axis = 1, inplace = True)
playersRoles.head()
# Out:
#    account_id  role
# 0    94155156     5
# 1    73562326     4
# 2   103735745     5
# 3   115102590     1
# 4    82262664     5

# %%
matchesWithoutLogs = matchesWithoutLogs.merge(playersRoles, left_on = 'account_id', right_on = 'account_id', how = 'left')
matchesWithoutLogs.shape
# Out:
# (5315, 202)

# %%
matchesWithoutLogs.drop_duplicates(subset = 'id_x', inplace = True)
matchesWithoutLogs.shape
# Out:
# (5010, 202)

# %%
matchesWithoutLogs.to_csv('ABT_09_05_2017.csv', na_rep = 'NaN', sep = ';')
