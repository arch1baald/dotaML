# %% [markdown]
# # Application of Machine Learning Methods to Analysis of Cyber-Sport Events
# ## Dmitry Savostyanov, 131
#
# ## Витрина данных по участникам Kiev Major
#
# ## Финальный файл скрипта: ABT_[DATE].csv
#
# В данном скрипте представлена таблица по командам, которые указаны в файле Dota Features & Snippets - Roles.csv за период с 1 января 2017 года по сегодняшний день. Строка таблицы - информация о матче на уровне игрока. Т.е. если между IG и LGD был матч с match_id = 12345, то таблица содержит 10 записей с данным идентификаторм для каждого конкретного account_id.

# %%
import urllib2
import json
import random
import datetime

import math 
import pandas as pd 
import numpy as np 
import sklearn 
import matplotlib.pyplot as plt 
from sklearn import svm, datasets 
# %matplotlib inline
plt.style.use('ggplot')

# %%
urlQuery = "https://api.opendota.com/api/explorer?sql=SELECT%0A%0A--%20Basic%20table%0Amatches.match_id%2C%0Aplayer_matches.account_id%2C%0Ateams.team_id%2C%0Amatches.leagueid%2C%0Aleagues.name%20leaguename%2C%0Amatches.start_time%2C%0Aplayer_matches.hero_id%2C%0Aplayer_matches.player_slot%2C%0A((player_matches.player_slot%20%3C%20128)%20%3D%20matches.radiant_win)%20win%2C%0Aplayer_matches.deaths%2C%0Aplayer_matches.assists%2C%0Aplayer_matches.gold_per_min%20%2C%0Aplayer_matches.xp_per_min%20%2C%0Aplayer_matches.gold_spent%20%2C%0Aplayer_matches.hero_damage%20%2C%0Aplayer_matches.tower_damage%20%2C%0Aplayer_matches.stuns%20%2C%0Aplayer_matches.creeps_stacked%20%2C%0Aplayer_matches.camps_stacked%20%2C%0Aplayer_matches.hero_healing%20%2C%0Amatches.duration%2C%0Amatches.cluster%2C%0Amatches.first_blood_time%2C%0A%0A--timeStamp%20variables%0Aplayer_matches.gold_t%5B3%5D%20t_Gold_cnt_3%2C%0Aplayer_matches.gold_t%5B5%5D%20t_Gold_cnt_5%2C%0Aplayer_matches.gold_t%5B8%5D%20t_Gold_cnt_8%2C%0Aplayer_matches.gold_t%5B10%5D%20t_Gold_cnt_10%2C%0Aplayer_matches.gold_t%5B12%5D%20t_Gold_cnt_12%2C%0Aplayer_matches.gold_t%5B15%5D%20t_Gold_cnt_15%2C%0Aplayer_matches.gold_t%5B20%5D%20t_Gold_cnt_20%2C%0Aplayer_matches.gold_t%5B25%5D%20t_Gold_cnt_25%2C%0Aplayer_matches.gold_t%5B30%5D%20t_Gold_cnt_30%2C%0A%0Aplayer_matches.lh_t%5B3%5D%20t_LastHits_cnt_3%2C%0Aplayer_matches.lh_t%5B5%5D%20t_LastHits_cnt_5%2C%0Aplayer_matches.lh_t%5B8%5D%20t_LastHits_cnt_8%2C%0Aplayer_matches.lh_t%5B10%5D%20t_LastHits_cnt_10%2C%0Aplayer_matches.lh_t%5B12%5D%20t_LastHits_cnt_12%2C%0Aplayer_matches.lh_t%5B15%5D%20t_LastHits_cnt_15%2C%0Aplayer_matches.lh_t%5B20%5D%20t_LastHits_cnt_20%2C%0Aplayer_matches.lh_t%5B25%5D%20t_LastHits_cnt_25%2C%0Aplayer_matches.lh_t%5B30%5D%20t_LastHits_cnt_30%2C%0A%0Aplayer_matches.xp_t%5B3%5D%20t_Experience_cnt_3%2C%0Aplayer_matches.xp_t%5B5%5D%20t_Experience_cnt_5%2C%0Aplayer_matches.xp_t%5B8%5D%20t_Experience_cnt_8%2C%0Aplayer_matches.xp_t%5B10%5D%20t_Experience_cnt_10%2C%0Aplayer_matches.xp_t%5B12%5D%20t_Experience_cnt_12%2C%0Aplayer_matches.xp_t%5B15%5D%20t_Experience_cnt_15%2C%0Aplayer_matches.xp_t%5B20%5D%20t_Experience_cnt_20%2C%0Aplayer_matches.xp_t%5B25%5D%20t_Experience_cnt_25%2C%0Aplayer_matches.xp_t%5B30%5D%20t_Experience_cnt_30%2C%0A%0Aplayer_matches.pings%20ping_log%2C%0Aplayer_matches.obs_log%2C%0Aplayer_matches.sen_log%2C%0Aplayer_matches.runes_log%2C%0Aplayer_matches.kills_log%2C%0Aplayer_matches.buyback_log%2C%0A%0A--table_heroStats%0Aheroes.localized_name%2C%0Aheroes.attack_type%2C%0Aheroes.primary_attr%2C%0Aheroes.roles%20role_log%2C%0A%0A--purchase_log%0Aplayer_matches.purchase_log%0A%0A%0AFROM%20matches%0AJOIN%20match_patch%20using(match_id)%0AJOIN%20leagues%20using(leagueid)%0AJOIN%20player_matches%20using(match_id)%0ALEFT%20JOIN%20notable_players%20using(account_id)%0ALEFT%20JOIN%20teams%20using(team_id)%0AJOIN%20heroes%20ON%20player_matches.hero_id%20%3D%20heroes.id%0A%0A%0AWHERE%20TRUE%0AAND%20teams.team_id%20in%0A%20%20%20%20(%0A%20%20%20%203%2C%0A%20%20%20%204%2C%0A%20%20%20%205%2C%0A%20%20%20%2015%2C%0A%20%20%20%2024%2C%0A%20%20%20%2036%2C%0A%20%20%20%2039%2C%0A%20%20%20%202163%2C%0A%20%20%20%20111474%2C%0A%20%20%20%20350190%2C%0A%20%20%20%20543897%2C%0A%20%20%20%20726228%2C%0A%20%20%20%201061269%2C%0A%20%20%20%201105664%2C%0A%20%20%20%201148284%2C%0A%20%20%20%201272244%2C%0A%20%20%20%201276785%2C%0A%20%20%20%201375614%2C%0A%20%20%20%201520578%2C%0A%20%20%20%201836806%2C%0A%20%20%20%201838315%2C%0A%20%20%20%201883502%2C%0A%20%20%20%202006913%2C%0A%20%20%20%202108395%2C%0A%20%20%20%202512249%2C%0A%20%20%20%202533075%2C%0A%20%20%20%202537636%2C%0A%20%20%20%202538753%2C%0A%20%20%20%202552670%2C%0A%20%20%20%202586976%2C%0A%20%20%20%202626685%2C%0A%20%20%20%202640025%2C%0A%20%20%20%202642171%2C%0A%20%20%20%202659468%2C%0A%20%20%20%202672298%2C%0A%20%20%20%202677025%2C%0A%20%20%20%202701329%2C%0A%20%20%20%202783913%2C%0A%20%20%20%202860081%2C%0A%20%20%20%202880140%2C%0A%20%20%20%203214108%2C%0A%20%20%20%203326126%2C%0A%20%20%20%203326875%2C%0A%20%20%20%203331948%0A%20%20%20%20)%0AAND%20matches.start_time%20%3E%3D%201483218000%0AORDER%20BY%20matches.match_id%20DESC%20NULLS%20LAST%0A--LIMIT%20200"

# %%
urlQuery = "https://api.opendota.com/api/explorer?sql=SELECT%0D%0A%0D%0A--%20Basic%20table%0D%0Amatches.match_id%2C%0D%0Aplayer_matches.account_id%2C%0D%0Ateams.team_id%2C%0D%0Amatches.leagueid%2C%0D%0Aleagues.name%20leaguename%2C%0D%0Amatches.start_time%2C%0D%0Aplayer_matches.hero_id%2C%0D%0Aplayer_matches.player_slot%2C%0D%0A((player_matches.player_slot%20%3C%20128)%20%3D%20matches.radiant_win)%20win%2C%0D%0Aplayer_matches.kills%2C%0D%0Aplayer_matches.deaths%2C%0D%0Aplayer_matches.assists%2C%0D%0Aplayer_matches.gold_per_min%20%2C%0D%0Aplayer_matches.xp_per_min%20%2C%0D%0Aplayer_matches.gold_spent%20%2C%0D%0Aplayer_matches.hero_damage%20%2C%0D%0Aplayer_matches.tower_damage%20%2C%0D%0Aplayer_matches.stuns%20%2C%0D%0Aplayer_matches.creeps_stacked%20%2C%0D%0Aplayer_matches.camps_stacked%20%2C%0D%0Aplayer_matches.hero_healing%20%2C%0D%0Aplayer_matches.last_hits%2C%0D%0Aplayer_matches.denies%2C%0D%0Aplayer_matches.level%2C%0D%0Amatches.duration%2C%0D%0Amatches.cluster%2C%0D%0Amatches.first_blood_time%2C%0D%0A%0D%0A--timeStamp%20variables%0D%0Aplayer_matches.gold_t%5B3%5D%20t_Gold_cnt_3%2C%0D%0Aplayer_matches.gold_t%5B5%5D%20t_Gold_cnt_5%2C%0D%0Aplayer_matches.gold_t%5B8%5D%20t_Gold_cnt_8%2C%0D%0Aplayer_matches.gold_t%5B10%5D%20t_Gold_cnt_10%2C%0D%0Aplayer_matches.gold_t%5B12%5D%20t_Gold_cnt_12%2C%0D%0Aplayer_matches.gold_t%5B15%5D%20t_Gold_cnt_15%2C%0D%0Aplayer_matches.gold_t%5B20%5D%20t_Gold_cnt_20%2C%0D%0Aplayer_matches.gold_t%5B25%5D%20t_Gold_cnt_25%2C%0D%0Aplayer_matches.gold_t%5B30%5D%20t_Gold_cnt_30%2C%0D%0A%0D%0Aplayer_matches.lh_t%5B3%5D%20t_LastHits_cnt_3%2C%0D%0Aplayer_matches.lh_t%5B5%5D%20t_LastHits_cnt_5%2C%0D%0Aplayer_matches.lh_t%5B8%5D%20t_LastHits_cnt_8%2C%0D%0Aplayer_matches.lh_t%5B10%5D%20t_LastHits_cnt_10%2C%0D%0Aplayer_matches.lh_t%5B12%5D%20t_LastHits_cnt_12%2C%0D%0Aplayer_matches.lh_t%5B15%5D%20t_LastHits_cnt_15%2C%0D%0Aplayer_matches.lh_t%5B20%5D%20t_LastHits_cnt_20%2C%0D%0Aplayer_matches.lh_t%5B25%5D%20t_LastHits_cnt_25%2C%0D%0Aplayer_matches.lh_t%5B30%5D%20t_LastHits_cnt_30%2C%0D%0A%0D%0Aplayer_matches.xp_t%5B3%5D%20t_Experience_cnt_3%2C%0D%0Aplayer_matches.xp_t%5B5%5D%20t_Experience_cnt_5%2C%0D%0Aplayer_matches.xp_t%5B8%5D%20t_Experience_cnt_8%2C%0D%0Aplayer_matches.xp_t%5B10%5D%20t_Experience_cnt_10%2C%0D%0Aplayer_matches.xp_t%5B12%5D%20t_Experience_cnt_12%2C%0D%0Aplayer_matches.xp_t%5B15%5D%20t_Experience_cnt_15%2C%0D%0Aplayer_matches.xp_t%5B20%5D%20t_Experience_cnt_20%2C%0D%0Aplayer_matches.xp_t%5B25%5D%20t_Experience_cnt_25%2C%0D%0Aplayer_matches.xp_t%5B30%5D%20t_Experience_cnt_30%2C%0D%0A%0D%0Aplayer_matches.pings%20ping_log%2C%0D%0Aplayer_matches.obs_log%2C%0D%0Aplayer_matches.sen_log%2C%0D%0Aplayer_matches.runes_log%2C%0D%0Aplayer_matches.kills_log%2C%0D%0Aplayer_matches.buyback_log%2C%0D%0A%0D%0A--table_heroStats%0D%0Aheroes.localized_name%2C%0D%0Aheroes.attack_type%2C%0D%0Aheroes.primary_attr%2C%0D%0Aheroes.roles%20role_log%2C%0D%0A%0D%0A--purchase_log%0D%0Aplayer_matches.purchase_log%0D%0A%0D%0A%0D%0AFROM%20matches%0D%0AJOIN%20match_patch%20using(match_id)%0D%0AJOIN%20leagues%20using(leagueid)%0D%0AJOIN%20player_matches%20using(match_id)%0D%0ALEFT%20JOIN%20notable_players%20using(account_id)%0D%0ALEFT%20JOIN%20teams%20using(team_id)%0D%0AJOIN%20heroes%20ON%20player_matches.hero_id%20%3D%20heroes.id%0D%0A%0D%0A%0D%0AWHERE%20TRUE%0D%0AAND%20teams.team_id%20in%0D%0A%20%20%20%20(%0D%0A%20%20%20%20%20%205%2C%0D%0A%09%20%2026%2C%0D%0A%09%20%2039%2C%0D%0A%09%20%202163%2C%0D%0A%09%20%201375614%2C%0D%0A%09%20%201836806%2C%0D%0A%09%20%201883502%2C%0D%0A%09%20%202108395%2C%0D%0A%09%20%202512249%2C%0D%0A%09%20%202586976%2C%0D%0A%09%20%202640025%2C%0D%0A%09%20%202642171%2C%0D%0A%09%20%203326875%2C%0D%0A%09%20%203722973%2C%0D%0A%09%20%203580606%2C%0D%0A%09%20%203547682%2C%0D%0A%09%20%204253054%2C%0D%0A%09%20%204251435%2C%0D%0A%09%20%201838315%0D%0A%20%20%20%20)%0D%0AAND%20matches.start_time%20%3E%3D%201483218000%0D%0AORDER%20BY%20matches.match_id%20DESC%20NULLS%20LAST%0D%0A--LIMIT%20200"'

# %% [markdown]
# # Загружаем данные в формате json, парсим и сохраняем в Pandas
#
# Предварительно ссылку стоит открыть в браузере, иначе она не хочет грузиться (слишком большая?)

# %%
response = urllib2.urlopen(urlQuery)
jsonResponse = response.read()
dictData = json.loads(jsonResponse)
matches = pd.DataFrame.from_dict(dictData['rows'])

# %% [markdown]
# # Добавляем уникальный идентификатор matchId_accountId и дату

# %%
matches['id'] = matches['match_id'].astype('str') + "_" + matches['account_id'].astype('str')
print matches.shape
matches['datetime'] = matches["start_time"].apply(lambda x: datetime.datetime.fromtimestamp(x).strftime('%d.%m.%Y %H:%M:%S'))
# Out:
# (10267, 62)

# %% [markdown]
# Данные содержат 10437 строки.

# %% [markdown]
# # Список переменных

# %%
list(matches)
# Out:
# [u'account_id',
#  u'assists',
#  u'attack_type',
#  u'buyback_log',
#  u'camps_stacked',
#  u'cluster',
#  u'creeps_stacked',
#  u'deaths',
#  u'duration',
#  u'first_blood_time',
#  u'gold_per_min',
#  u'gold_spent',
#  u'hero_damage',
#  u'hero_healing',
#  u'hero_id',
#  u'kills_log',
#  u'leagueid',
#  u'leaguename',
#  u'localized_name',
#  u'match_id',
#  u'obs_log',
#  u'ping_log',
#  u'player_slot',
#  u'primary_attr',
#  u'purchase_log',
#  u'role_log',
#  u'runes_log',
#  u'sen_log',
#  u'start_time',
#  u'stuns',
#  u't_experience_cnt_10',
#  u't_experience_cnt_12',
#  u't_experience_cnt_15',
#  u't_experience_cnt_20',
#  u't_experience_cnt_25',
#  u't_experience_cnt_3',
#  u't_experience_cnt_30',
#  u't_experience_cnt_5',
#  u't_experience_cnt_8',
#  u't_gold_cnt_10',
#  u't_gold_cnt_12',
#  u't_gold_cnt_15',
#  u't_gold_cnt_20',
#  u't_gold_cnt_25',
#  u't_gold_cnt_3',
#  u't_gold_cnt_30',
#  u't_gold_cnt_5',
#  u't_gold_cnt_8',
#  u't_lasthits_cnt_10',
#  u't_lasthits_cnt_12',
#  u't_lasthits_cnt_15',
#  u't_lasthits_cnt_20',
#  u't_lasthits_cnt_25',
#  u't_lasthits_cnt_3',
#  u't_lasthits_cnt_30',
#  u't_lasthits_cnt_5',
#  u't_lasthits_cnt_8',
#  u'team_id',
#  u'tower_damage',
#  u'win',
#  u'xp_per_min',
#  'id',
#  'datetime']

# %%
matches.head()
# Out:
#    account_id  assists attack_type buyback_log  camps_stacked  cluster  \
# 0    89166519       19      Ranged          []            0.0      224
# 1   139174891       12      Ranged          []            0.0      224
# 2   173812218        9       Melee          []            1.0      224
# 3   110837826        7       Melee          []            0.0      224
# 4   157475523       16       Melee          []            1.0      224
#
#    creeps_stacked  deaths  duration  first_blood_time         ...           \
# 0             0.0       3      1454                 0         ...
# 1             0.0       2      1454                 0         ...
# 2             2.0       6      1454                 0         ...
# 3             0.0       2      1454                 0         ...
# 4             2.0       3      1454                 0         ...
#
#    t_lasthits_cnt_3  t_lasthits_cnt_30  t_lasthits_cnt_5  t_lasthits_cnt_8  \
# 0               0.0               17.0               0.0               0.0
# 1               8.0              172.0              17.0              29.0
# 2               0.0               30.0               0.0               0.0
# 3               8.0               87.0              24.0              42.0
# 4               7.0              158.0              17.0              34.0
#
#    team_id tower_damage   win xp_per_min                    id  \
# 0  2860081          336  True        316   3128895476_89166519
# 1  2860081         5013  True        640  3128895476_139174891
# 2  2860081          383  True        320  3128895476_173812218
# 3  2860081          751  True        533  3128895476_110837826
# 4  2860081          396  True        607  3128895476_157475523
#
#               datetime
# 0  20.04.2017 09:57:33
# 1  20.04.2017 09:57:33
# 2  20.04.2017 09:57:33
# 3  20.04.2017 09:57:33
# 4  20.04.2017 09:57:33
#
# [5 rows x 63 columns]

# %%
matches.tail()
# Out:
#        account_id  assists attack_type  \
# 10262   135384059        5       Melee
# 10263   114239371       15      Ranged
# 10264   139937922       16       Melee
# 10265   135384059       13       Melee
# 10266   139280377       13      Ranged
#
#                                              buyback_log  camps_stacked  \
# 10262                                                 []            0.0
# 10263                                                 []            0.0
# 10264  [{u'slot': 3, u'type': u'buyback_log', u'playe...            0.0
# 10265                                                 []            2.0
# 10266                                                 []            0.0
#
#        cluster  creeps_stacked  deaths  duration  first_blood_time  \
# 10262      224             0.0      15      2855                 9
# 10263      224             0.0       6      2643                10
# 10264      224             0.0      11      2643                10
# 10265      224             5.0       7      2643                10
# 10266      224             0.0       7      2643                10
#
#               ...           t_lasthits_cnt_3  t_lasthits_cnt_30  \
# 10262         ...                        1.0               24.0
# 10263         ...                        2.0               11.0
# 10264         ...                       11.0              156.0
# 10265         ...                        1.0               45.0
# 10266         ...                        5.0              175.0
#
#        t_lasthits_cnt_5  t_lasthits_cnt_8  team_id tower_damage    win  \
# 10262               1.0               1.0   726228          123  False
# 10263               3.0               3.0   726228          139  False
# 10264              20.0              34.0   726228          250  False
# 10265               1.0               3.0   726228            0  False
# 10266              15.0              32.0   726228         3108  False
#
#       xp_per_min                    id             datetime
# 10262        260  2886032793_135384059  01.01.2017 09:08:12
# 10263        224  2885942991_114239371  01.01.2017 08:06:56
# 10264        450  2885942991_139937922  01.01.2017 08:06:56
# 10265        278  2885942991_135384059  01.01.2017 08:06:56
# 10266        548  2885942991_139280377  01.01.2017 08:06:56
#
# [5 rows x 63 columns]

# %% [markdown]
# # Parse Items Timing

# %%
t_item = dict()
itemList = [
            'blink',
            'power_treads',
            'ultimate_scepter',
            'phase_boots',
            'travel_boots',
            'blade_mail',
            'arcane_boots',
            'black_king_bar',
            'desolator',
            'magic_wand',
            'tranquil_boots',
            'invis_sword',
            'echo_sabre',
            'manta',
            'ring_of_aquila',
            'force_staff',
            'aether_lens',
            'wind_lace',
            'silver_edge',
            'hand_of_midas',
            'sphere',
            'boots',
            'hurricane_pike',
            'bottle'            
            ]
columnNames = ['id']

for item in itemList:
    columnNames.append("t_item_" + item)

items = pd.DataFrame(columns = columnNames)
    
for i in range(0, len(matches['purchase_log'])):
    
    purchaseList = matches['purchase_log'][i]     
    for item in itemList:
        columnName = "t_item_" + item
        t_item[columnName] = np.nan
        
    if purchaseList is not None:
        for purchase in purchaseList:
            for item in itemList:
                columnName = "t_item_" + item
                if purchase['key'] == item and purchase['time'] < 30*60:
                    t_item[columnName] = purchase['time']
                    unique_id = matches['match_id'][i].astype('str') + "_" + matches['account_id'][i].astype('str')
                    t_item['id'] = unique_id
        itemsRow = pd.DataFrame.from_dict(t_item, orient = 'index').transpose()
        items = items.append(itemsRow, ignore_index=True)           
    else: print "Line %s: Log does not exists" %i
# Out:
# Line 55: Log does not exists
# Line 61: Log does not exists
# Line 415: Log does not exists
# Line 416: Log does not exists
# Line 785: Log does not exists
# Line 786: Log does not exists
# Line 787: Log does not exists
# Line 788: Log does not exists
# Line 789: Log does not exists
# Line 790: Log does not exists
# Line 810: Log does not exists
# Line 920: Log does not exists
# Line 921: Log does not exists
# Line 922: Log does not exists
# Line 923: Log does not exists
# Line 924: Log does not exists
# Line 2772: Log does not exists
# Line 2773: Log does not exists
# Line 2948: Log does not exists
# Line 2949: Log does not exists
# Line 2950: Log does not exists
# Line 2951: Log does not exists
# Line 2952: Log does not exists
# Line 3832: Log does not exists
# Line 3833: Log does not exists
# Line 3834: Log does not exists
# Line 3835: Log does not exists
# Line 3836: Log does not exists
# Line 3837: Log does not exists
# Line 3838: Log does not exists
# Line 3839: Log does not exists
# Line 3840: Log does not exists
# Line 4353: Log does not exists
# Line 4354: Log does not exists
# Line 4355: Log does not exists
# Line 4356: Log does not exists
# Line 4357: Log does not exists
# Line 4423: Log does not exists
# Line 4424: Log does not exists
# Line 4425: Log does not exists
# Line 4426: Log does not exists
# Line 4427: Log does not exists
# Line 4428: Log does not exists
# Line 4429: Log does not exists
# Line 4430: Log does not exists
# Line 4431: Log does not exists
# Line 4432: Log does not exists
# Line 4522: Log does not exists
# Line 4523: Log does not exists
# Line 4524: Log does not exists
# Line 4525: Log does not exists
# Line 4526: Log does not exists
# Line 4718: Log does not exists
# Line 4719: Log does not exists
# Line 4720: Log does not exists
# Line 4721: Log does not exists
# Line 4722: Log does not exists

# %%
items.shape
# Out:
# (10210, 25)

# %%
matches = matches.merge(items, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (10210, 88)

# %% [markdown]
# 73 записи было удалено из таблицы в связи с отсутствием логов о покупках игроков.

# %% [markdown]
# # First Kill Timing (Время в секундах от старта первой пачки крипов)

# %%
for i in range(0, len(matches)):
    matches.loc[i, 't_first_kill'] = 0
    try:
        t_first_kill = matches['kills_log'][i][0]['time']
    except Exception:
        print "Line %s: Player has 0 kills" %i
    if t_first_kill is not None:
        matches.loc[i, 't_first_kill'] = t_first_kill
# Out:
# Line 6: Player has 0 kills
# Line 16: Player has 0 kills
# Line 17: Player has 0 kills
# Line 40: Player has 0 kills
# Line 47: Player has 0 kills
# Line 58: Player has 0 kills
# Line 68: Player has 0 kills
# Line 78: Player has 0 kills
# Line 87: Player has 0 kills
# Line 94: Player has 0 kills
# Line 123: Player has 0 kills
# Line 147: Player has 0 kills
# Line 148: Player has 0 kills
# Line 174: Player has 0 kills
# Line 226: Player has 0 kills
# Line 252: Player has 0 kills
# Line 263: Player has 0 kills
# Line 265: Player has 0 kills
# Line 280: Player has 0 kills
# Line 281: Player has 0 kills
# Line 284: Player has 0 kills
# Line 286: Player has 0 kills
# Line 334: Player has 0 kills
# Line 338: Player has 0 kills
# Line 375: Player has 0 kills
# Line 380: Player has 0 kills
# Line 382: Player has 0 kills
# Line 387: Player has 0 kills
# Line 395: Player has 0 kills
# Line 401: Player has 0 kills
# Line 415: Player has 0 kills
# Line 417: Player has 0 kills
# Line 433: Player has 0 kills
# Line 448: Player has 0 kills
# Line 515: Player has 0 kills
# Line 521: Player has 0 kills
# Line 522: Player has 0 kills
# Line 538: Player has 0 kills
# Line 575: Player has 0 kills
# Line 610: Player has 0 kills
# Line 645: Player has 0 kills
# Line 657: Player has 0 kills
# Line 665: Player has 0 kills
# Line 678: Player has 0 kills
# Line 685: Player has 0 kills
# Line 695: Player has 0 kills
# Line 697: Player has 0 kills
# Line 716: Player has 0 kills
# Line 772: Player has 0 kills
# Line 784: Player has 0 kills
# Line 831: Player has 0 kills
# Line 833: Player has 0 kills
# Line 837: Player has 0 kills
# Line 838: Player has 0 kills
# Line 839: Player has 0 kills
# Line 845: Player has 0 kills
# Line 878: Player has 0 kills
# Line 883: Player has 0 kills
# Line 886: Player has 0 kills
# Line 887: Player has 0 kills
# Line 889: Player has 0 kills
# Line 891: Player has 0 kills
# Line 909: Player has 0 kills
# Line 915: Player has 0 kills
# Line 951: Player has 0 kills
# Line 957: Player has 0 kills
# Line 990: Player has 0 kills
# Line 1015: Player has 0 kills
# Line 1019: Player has 0 kills
# Line 1057: Player has 0 kills
# Line 1101: Player has 0 kills
# Line 1102: Player has 0 kills
# Line 1128: Player has 0 kills
# Line 1139: Player has 0 kills
# Line 1171: Player has 0 kills
# Line 1187: Player has 0 kills
# Line 1224: Player has 0 kills
# Line 1234: Player has 0 kills
# Line 1244: Player has 0 kills
# Line 1283: Player has 0 kills
# Line 1298: Player has 0 kills
# Line 1334: Player has 0 kills
# Line 1351: Player has 0 kills
# Line 1365: Player has 0 kills
# Line 1369: Player has 0 kills
# Line 1370: Player has 0 kills
# Line 1373: Player has 0 kills
# Line 1379: Player has 0 kills
# Line 1381: Player has 0 kills
# Line 1418: Player has 0 kills
# Line 1448: Player has 0 kills
# Line 1465: Player has 0 kills
# Line 1475: Player has 0 kills
# Line 1478: Player has 0 kills
# Line 1480: Player has 0 kills
# Line 1522: Player has 0 kills
# Line 1524: Player has 0 kills
# Line 1525: Player has 0 kills
# Line 1532: Player has 0 kills
# Line 1557: Player has 0 kills
# Line 1560: Player has 0 kills
# Line 1572: Player has 0 kills
# Line 1575: Player has 0 kills
# Line 1585: Player has 0 kills
# Line 1587: Player has 0 kills
# Line 1589: Player has 0 kills
# Line 1610: Player has 0 kills
# Line 1651: Player has 0 kills
# Line 1660: Player has 0 kills
# Line 1661: Player has 0 kills
# Line 1665: Player has 0 kills
# Line 1666: Player has 0 kills
# Line 1668: Player has 0 kills
# Line 1679: Player has 0 kills
# Line 1688: Player has 0 kills
# Line 1709: Player has 0 kills
# Line 1713: Player has 0 kills
# Line 1715: Player has 0 kills
# Line 1717: Player has 0 kills
# Line 1746: Player has 0 kills
# Line 1750: Player has 0 kills
# Line 1769: Player has 0 kills
# Line 1774: Player has 0 kills
# Line 1781: Player has 0 kills
# Line 1784: Player has 0 kills
# Line 1810: Player has 0 kills
# Line 1815: Player has 0 kills
# Line 1845: Player has 0 kills
# Line 1846: Player has 0 kills
# Line 1851: Player has 0 kills
# Line 1854: Player has 0 kills
# Line 1856: Player has 0 kills
# Line 1858: Player has 0 kills
# Line 1872: Player has 0 kills
# Line 1882: Player has 0 kills
# Line 1886: Player has 0 kills
# Line 1928: Player has 0 kills
# Line 1943: Player has 0 kills
# Line 1949: Player has 0 kills
# Line 1970: Player has 0 kills
# Line 1971: Player has 0 kills
# Line 1974: Player has 0 kills
# Line 1978: Player has 0 kills
# Line 1990: Player has 0 kills
# Line 2005: Player has 0 kills
# Line 2014: Player has 0 kills
# Line 2020: Player has 0 kills
# Line 2029: Player has 0 kills
# Line 2039: Player has 0 kills
# Line 2058: Player has 0 kills
# Line 2059: Player has 0 kills
# Line 2063: Player has 0 kills
# Line 2073: Player has 0 kills
# Line 2085: Player has 0 kills
# Line 2126: Player has 0 kills
# Line 2132: Player has 0 kills
# Line 2152: Player has 0 kills
# Line 2159: Player has 0 kills
# Line 2162: Player has 0 kills
# Line 2166: Player has 0 kills
# Line 2179: Player has 0 kills
# Line 2212: Player has 0 kills
# Line 2218: Player has 0 kills
# Line 2220: Player has 0 kills
# Line 2265: Player has 0 kills
# Line 2297: Player has 0 kills
# Line 2335: Player has 0 kills
# Line 2376: Player has 0 kills
# Line 2421: Player has 0 kills
# Line 2430: Player has 0 kills
# Line 2451: Player has 0 kills
# Line 2465: Player has 0 kills
# Line 2480: Player has 0 kills
# Line 2485: Player has 0 kills
# Line 2507: Player has 0 kills
# Line 2536: Player has 0 kills
# Line 2548: Player has 0 kills
# Line 2565: Player has 0 kills
# Line 2574: Player has 0 kills
# Line 2578: Player has 0 kills
# Line 2589: Player has 0 kills
# Line 2608: Player has 0 kills
# Line 2609: Player has 0 kills
# Line 2620: Player has 0 kills
# Line 2647: Player has 0 kills
# Line 2684: Player has 0 kills
# Line 2692: Player has 0 kills
# Line 2721: Player has 0 kills
# Line 2723: Player has 0 kills
# Line 2745: Player has 0 kills
# Line 2752: Player has 0 kills
# Line 2808: Player has 0 kills
# Line 2848: Player has 0 kills
# Line 2861: Player has 0 kills
# Line 2889: Player has 0 kills
# Line 2902: Player has 0 kills
# Line 2912: Player has 0 kills
# Line 2935: Player has 0 kills
# Line 2942: Player has 0 kills
# Line 3021: Player has 0 kills
# Line 3057: Player has 0 kills
# Line 3060: Player has 0 kills
# Line 3063: Player has 0 kills
# Line 3085: Player has 0 kills
# Line 3090: Player has 0 kills
# Line 3112: Player has 0 kills
# Line 3119: Player has 0 kills
# Line 3151: Player has 0 kills
# Line 3178: Player has 0 kills
# Line 3212: Player has 0 kills
# Line 3213: Player has 0 kills
# Line 3243: Player has 0 kills
# Line 3251: Player has 0 kills
# Line 3266: Player has 0 kills
# Line 3278: Player has 0 kills
# Line 3293: Player has 0 kills
# Line 3322: Player has 0 kills
# Line 3330: Player has 0 kills
# Line 3376: Player has 0 kills
# Line 3409: Player has 0 kills
# Line 3420: Player has 0 kills
# Line 3429: Player has 0 kills
# Line 3434: Player has 0 kills
# Line 3456: Player has 0 kills
# Line 3464: Player has 0 kills
# Line 3473: Player has 0 kills
# Line 3482: Player has 0 kills
# Line 3496: Player has 0 kills
# Line 3498: Player has 0 kills
# Line 3529: Player has 0 kills
# Line 3534: Player has 0 kills
# Line 3536: Player has 0 kills
# Line 3541: Player has 0 kills
# Line 3584: Player has 0 kills
# Line 3606: Player has 0 kills
# Line 3614: Player has 0 kills
# Line 3616: Player has 0 kills
# Line 3629: Player has 0 kills
# Line 3630: Player has 0 kills
# Line 3635: Player has 0 kills
# Line 3648: Player has 0 kills
# Line 3654: Player has 0 kills
# Line 3662: Player has 0 kills
# Line 3713: Player has 0 kills
# Line 3759: Player has 0 kills
# Line 3775: Player has 0 kills
# Line 3780: Player has 0 kills
# Line 3798: Player has 0 kills
# Line 3808: Player has 0 kills
# Line 3819: Player has 0 kills
# Line 3828: Player has 0 kills
# Line 3831: Player has 0 kills
# Line 3835: Player has 0 kills
# Line 3842: Player has 0 kills
# Line 3849: Player has 0 kills
# Line 3868: Player has 0 kills
# Line 3873: Player has 0 kills
# Line 3874: Player has 0 kills
# Line 3878: Player has 0 kills
# Line 3879: Player has 0 kills
# Line 3880: Player has 0 kills
# Line 3881: Player has 0 kills
# Line 3882: Player has 0 kills
# Line 3888: Player has 0 kills
# Line 3889: Player has 0 kills
# Line 3899: Player has 0 kills
# Line 3901: Player has 0 kills
# Line 3902: Player has 0 kills
# Line 3918: Player has 0 kills
# Line 3919: Player has 0 kills
# Line 3920: Player has 0 kills
# Line 3928: Player has 0 kills
# Line 3945: Player has 0 kills
# Line 3946: Player has 0 kills
# Line 3955: Player has 0 kills
# Line 3973: Player has 0 kills
# Line 3982: Player has 0 kills
# Line 4034: Player has 0 kills
# Line 4048: Player has 0 kills
# Line 4056: Player has 0 kills
# Line 4075: Player has 0 kills
# Line 4083: Player has 0 kills
# Line 4093: Player has 0 kills
# Line 4103: Player has 0 kills
# Line 4109: Player has 0 kills
# Line 4127: Player has 0 kills
# Line 4132: Player has 0 kills
# Line 4180: Player has 0 kills
# Line 4185: Player has 0 kills
# Line 4201: Player has 0 kills
# Line 4209: Player has 0 kills
# Line 4212: Player has 0 kills
# Line 4224: Player has 0 kills
# Line 4230: Player has 0 kills
# Line 4259: Player has 0 kills
# Line 4261: Player has 0 kills
# Line 4273: Player has 0 kills
# Line 4275: Player has 0 kills
# Line 4287: Player has 0 kills
# Line 4289: Player has 0 kills
# Line 4300: Player has 0 kills
# Line 4301: Player has 0 kills
# Line 4302: Player has 0 kills
# Line 4353: Player has 0 kills
# Line 4355: Player has 0 kills
# Line 4357: Player has 0 kills
# Line 4380: Player has 0 kills
# Line 4389: Player has 0 kills
# Line 4397: Player has 0 kills
# Line 4423: Player has 0 kills
# Line 4426: Player has 0 kills
# Line 4427: Player has 0 kills
# Line 4454: Player has 0 kills
# Line 4457: Player has 0 kills
# Line 4460: Player has 0 kills
# Line 4477: Player has 0 kills
# Line 4493: Player has 0 kills
# Line 4494: Player has 0 kills
# Line 4534: Player has 0 kills
# Line 4537: Player has 0 kills
# Line 4543: Player has 0 kills
# Line 4568: Player has 0 kills
# Line 4574: Player has 0 kills
# Line 4579: Player has 0 kills
# Line 4587: Player has 0 kills
# Line 4610: Player has 0 kills
# Line 4615: Player has 0 kills
# Line 4626: Player has 0 kills
# Line 4680: Player has 0 kills
# Line 4696: Player has 0 kills
# Line 4697: Player has 0 kills
# Line 4698: Player has 0 kills
# Line 4704: Player has 0 kills
# Line 4705: Player has 0 kills
# Line 4721: Player has 0 kills
# Line 4761: Player has 0 kills
# Line 4796: Player has 0 kills
# Line 4811: Player has 0 kills
# Line 4816: Player has 0 kills
# Line 4828: Player has 0 kills
# Line 4854: Player has 0 kills
# Line 4855: Player has 0 kills
# Line 4888: Player has 0 kills
# Line 4900: Player has 0 kills
# Line 4912: Player has 0 kills
# Line 4934: Player has 0 kills
# Line 4935: Player has 0 kills
# Line 4972: Player has 0 kills
# Line 4981: Player has 0 kills
# Line 4987: Player has 0 kills
# Line 5029: Player has 0 kills
# Line 5043: Player has 0 kills
# Line 5045: Player has 0 kills
# Line 5052: Player has 0 kills
# Line 5067: Player has 0 kills
# Line 5085: Player has 0 kills
# Line 5094: Player has 0 kills
# Line 5107: Player has 0 kills
# Line 5114: Player has 0 kills
# Line 5131: Player has 0 kills
# Line 5161: Player has 0 kills
# Line 5165: Player has 0 kills
# Line 5179: Player has 0 kills
# Line 5181: Player has 0 kills
# Line 5182: Player has 0 kills
# Line 5185: Player has 0 kills
# Line 5200: Player has 0 kills
# Line 5202: Player has 0 kills
# Line 5204: Player has 0 kills
# Line 5211: Player has 0 kills
# Line 5232: Player has 0 kills
# Line 5235: Player has 0 kills
# Line 5243: Player has 0 kills
# Line 5260: Player has 0 kills
# Line 5273: Player has 0 kills
# Line 5276: Player has 0 kills
# Line 5296: Player has 0 kills
# Line 5315: Player has 0 kills
# Line 5352: Player has 0 kills
# Line 5354: Player has 0 kills
# Line 5373: Player has 0 kills
# Line 5382: Player has 0 kills
# Line 5384: Player has 0 kills
# Line 5385: Player has 0 kills
# Line 5389: Player has 0 kills
# Line 5400: Player has 0 kills
# Line 5409: Player has 0 kills
# Line 5419: Player has 0 kills
# Line 5433: Player has 0 kills
# Line 5436: Player has 0 kills
# Line 5465: Player has 0 kills
# Line 5500: Player has 0 kills
# Line 5512: Player has 0 kills
# Line 5542: Player has 0 kills
# Line 5543: Player has 0 kills
# Line 5545: Player has 0 kills
# Line 5554: Player has 0 kills
# Line 5557: Player has 0 kills
# Line 5578: Player has 0 kills
# Line 5588: Player has 0 kills
# Line 5597: Player has 0 kills
# Line 5614: Player has 0 kills
# Line 5626: Player has 0 kills
# Line 5634: Player has 0 kills
# Line 5641: Player has 0 kills
# Line 5657: Player has 0 kills
# Line 5661: Player has 0 kills
# Line 5664: Player has 0 kills
# Line 5673: Player has 0 kills
# Line 5691: Player has 0 kills
# Line 5716: Player has 0 kills
# Line 5728: Player has 0 kills
# Line 5767: Player has 0 kills
# Line 5778: Player has 0 kills
# Line 5795: Player has 0 kills
# Line 5796: Player has 0 kills
# Line 5798: Player has 0 kills
# Line 5799: Player has 0 kills
# Line 5801: Player has 0 kills
# Line 5808: Player has 0 kills
# Line 5840: Player has 0 kills
# Line 5860: Player has 0 kills
# Line 5862: Player has 0 kills
# Line 5891: Player has 0 kills
# Line 5895: Player has 0 kills
# Line 5919: Player has 0 kills
# Line 5945: Player has 0 kills
# Line 5958: Player has 0 kills
# Line 5968: Player has 0 kills
# Line 6003: Player has 0 kills
# Line 6016: Player has 0 kills
# Line 6023: Player has 0 kills
# Line 6026: Player has 0 kills
# Line 6035: Player has 0 kills
# Line 6096: Player has 0 kills
# Line 6097: Player has 0 kills
# Line 6134: Player has 0 kills
# Line 6151: Player has 0 kills
# Line 6198: Player has 0 kills
# Line 6203: Player has 0 kills
# Line 6211: Player has 0 kills
# Line 6217: Player has 0 kills
# Line 6218: Player has 0 kills
# Line 6263: Player has 0 kills
# Line 6274: Player has 0 kills
# Line 6284: Player has 0 kills
# Line 6328: Player has 0 kills
# Line 6344: Player has 0 kills
# Line 6359: Player has 0 kills
# Line 6388: Player has 0 kills
# Line 6414: Player has 0 kills
# Line 6416: Player has 0 kills
# Line 6419: Player has 0 kills
# Line 6422: Player has 0 kills
# Line 6428: Player has 0 kills
# Line 6463: Player has 0 kills
# Line 6467: Player has 0 kills
# Line 6473: Player has 0 kills
# Line 6474: Player has 0 kills
# Line 6485: Player has 0 kills
# Line 6487: Player has 0 kills
# Line 6502: Player has 0 kills
# Line 6503: Player has 0 kills
# Line 6508: Player has 0 kills
# Line 6510: Player has 0 kills
# Line 6516: Player has 0 kills
# Line 6526: Player has 0 kills
# Line 6538: Player has 0 kills
# Line 6557: Player has 0 kills
# Line 6568: Player has 0 kills
# Line 6582: Player has 0 kills
# Line 6586: Player has 0 kills
# Line 6587: Player has 0 kills
# Line 6589: Player has 0 kills
# Line 6600: Player has 0 kills
# Line 6601: Player has 0 kills
# Line 6603: Player has 0 kills
# Line 6610: Player has 0 kills
# Line 6617: Player has 0 kills
# Line 6627: Player has 0 kills
# Line 6628: Player has 0 kills
# Line 6647: Player has 0 kills
# Line 6655: Player has 0 kills
# Line 6659: Player has 0 kills
# Line 6662: Player has 0 kills
# Line 6664: Player has 0 kills
# Line 6669: Player has 0 kills
# Line 6704: Player has 0 kills
# Line 6728: Player has 0 kills
# Line 6731: Player has 0 kills
# Line 6737: Player has 0 kills
# Line 6746: Player has 0 kills
# Line 6748: Player has 0 kills
# Line 6749: Player has 0 kills
# Line 6750: Player has 0 kills
# Line 6756: Player has 0 kills
# Line 6767: Player has 0 kills
# Line 6768: Player has 0 kills
# Line 6772: Player has 0 kills
# Line 6775: Player has 0 kills
# Line 6791: Player has 0 kills
# Line 6794: Player has 0 kills
# Line 6801: Player has 0 kills
# Line 6807: Player has 0 kills
# Line 6810: Player has 0 kills
# Line 6821: Player has 0 kills
# Line 6834: Player has 0 kills
# Line 6843: Player has 0 kills
# Line 6867: Player has 0 kills
# Line 6868: Player has 0 kills
# Line 6873: Player has 0 kills
# Line 6882: Player has 0 kills
# Line 6883: Player has 0 kills
# Line 6884: Player has 0 kills
# Line 6898: Player has 0 kills
# Line 6903: Player has 0 kills
# Line 6909: Player has 0 kills
# Line 6917: Player has 0 kills
# Line 6935: Player has 0 kills
# Line 6936: Player has 0 kills
# Line 6937: Player has 0 kills
# Line 6940: Player has 0 kills
# Line 6967: Player has 0 kills
# Line 6969: Player has 0 kills
# Line 6970: Player has 0 kills
# Line 6974: Player has 0 kills
# Line 6975: Player has 0 kills
# Line 6978: Player has 0 kills
# Line 6983: Player has 0 kills
# Line 6985: Player has 0 kills
# Line 6992: Player has 0 kills
# Line 7008: Player has 0 kills
# Line 7015: Player has 0 kills
# Line 7017: Player has 0 kills
# Line 7042: Player has 0 kills
# Line 7044: Player has 0 kills
# Line 7049: Player has 0 kills
# Line 7060: Player has 0 kills
# Line 7087: Player has 0 kills
# Line 7089: Player has 0 kills
# Line 7094: Player has 0 kills
# Line 7103: Player has 0 kills
# Line 7131: Player has 0 kills
# Line 7160: Player has 0 kills
# Line 7167: Player has 0 kills
# Line 7186: Player has 0 kills
# Line 7192: Player has 0 kills
# Line 7193: Player has 0 kills
# Line 7195: Player has 0 kills
# Line 7199: Player has 0 kills
# Line 7200: Player has 0 kills
# Line 7211: Player has 0 kills
# Line 7215: Player has 0 kills
# Line 7216: Player has 0 kills
# Line 7219: Player has 0 kills
# Line 7234: Player has 0 kills
# Line 7245: Player has 0 kills
# Line 7248: Player has 0 kills
# Line 7249: Player has 0 kills
# Line 7257: Player has 0 kills
# Line 7259: Player has 0 kills
# Line 7260: Player has 0 kills
# Line 7269: Player has 0 kills
# Line 7288: Player has 0 kills
# Line 7290: Player has 0 kills
# Line 7293: Player has 0 kills
# Line 7298: Player has 0 kills
# Line 7349: Player has 0 kills
# Line 7356: Player has 0 kills
# Line 7359: Player has 0 kills
# Line 7371: Player has 0 kills
# Line 7375: Player has 0 kills
# Line 7389: Player has 0 kills
# Line 7398: Player has 0 kills
# Line 7402: Player has 0 kills
# Line 7409: Player has 0 kills
# Line 7441: Player has 0 kills
# Line 7443: Player has 0 kills
# Line 7445: Player has 0 kills
# Line 7456: Player has 0 kills
# Line 7479: Player has 0 kills
# Line 7493: Player has 0 kills
# Line 7494: Player has 0 kills
# Line 7517: Player has 0 kills
# Line 7526: Player has 0 kills
# Line 7528: Player has 0 kills
# Line 7538: Player has 0 kills
# Line 7545: Player has 0 kills
# Line 7547: Player has 0 kills
# Line 7556: Player has 0 kills
# Line 7579: Player has 0 kills
# Line 7585: Player has 0 kills
# Line 7592: Player has 0 kills
# Line 7604: Player has 0 kills
# Line 7607: Player has 0 kills
# Line 7608: Player has 0 kills
# Line 7612: Player has 0 kills
# Line 7613: Player has 0 kills
# Line 7618: Player has 0 kills
# Line 7626: Player has 0 kills
# Line 7627: Player has 0 kills
# Line 7699: Player has 0 kills
# Line 7705: Player has 0 kills
# Line 7707: Player has 0 kills
# Line 7716: Player has 0 kills
# Line 7731: Player has 0 kills
# Line 7738: Player has 0 kills
# Line 7748: Player has 0 kills
# Line 7753: Player has 0 kills
# Line 7777: Player has 0 kills
# Line 7784: Player has 0 kills
# Line 7797: Player has 0 kills
# Line 7820: Player has 0 kills
# Line 7832: Player has 0 kills
# Line 7833: Player has 0 kills
# Line 7834: Player has 0 kills
# Line 7841: Player has 0 kills
# Line 7845: Player has 0 kills
# Line 7855: Player has 0 kills
# Line 7881: Player has 0 kills
# Line 7882: Player has 0 kills
# Line 7893: Player has 0 kills
# Line 7910: Player has 0 kills
# Line 7914: Player has 0 kills
# Line 7948: Player has 0 kills
# Line 7949: Player has 0 kills
# Line 7964: Player has 0 kills
# Line 7979: Player has 0 kills
# Line 8023: Player has 0 kills
# Line 8034: Player has 0 kills
# Line 8035: Player has 0 kills
# Line 8073: Player has 0 kills
# Line 8083: Player has 0 kills
# Line 8087: Player has 0 kills
# Line 8089: Player has 0 kills
# Line 8095: Player has 0 kills
# Line 8102: Player has 0 kills
# Line 8104: Player has 0 kills
# Line 8109: Player has 0 kills
# Line 8116: Player has 0 kills
# Line 8141: Player has 0 kills
# Line 8149: Player has 0 kills
# Line 8181: Player has 0 kills
# Line 8194: Player has 0 kills
# Line 8206: Player has 0 kills
# Line 8208: Player has 0 kills
# Line 8210: Player has 0 kills
# Line 8225: Player has 0 kills
# Line 8226: Player has 0 kills
# Line 8227: Player has 0 kills
# Line 8228: Player has 0 kills
# Line 8229: Player has 0 kills
# Line 8230: Player has 0 kills
# Line 8232: Player has 0 kills
# Line 8238: Player has 0 kills
# Line 8268: Player has 0 kills
# Line 8272: Player has 0 kills
# Line 8273: Player has 0 kills
# Line 8286: Player has 0 kills
# Line 8294: Player has 0 kills
# Line 8298: Player has 0 kills
# Line 8326: Player has 0 kills
# Line 8345: Player has 0 kills
# Line 8352: Player has 0 kills
# Line 8363: Player has 0 kills
# Line 8390: Player has 0 kills
# Line 8395: Player has 0 kills
# Line 8410: Player has 0 kills
# Line 8412: Player has 0 kills
# Line 8415: Player has 0 kills
# Line 8419: Player has 0 kills
# Line 8428: Player has 0 kills
# Line 8452: Player has 0 kills
# Line 8471: Player has 0 kills
# Line 8494: Player has 0 kills
# Line 8495: Player has 0 kills
# Line 8496: Player has 0 kills
# Line 8514: Player has 0 kills
# Line 8515: Player has 0 kills
# Line 8516: Player has 0 kills
# Line 8517: Player has 0 kills
# Line 8530: Player has 0 kills
# Line 8570: Player has 0 kills
# Line 8592: Player has 0 kills
# Line 8642: Player has 0 kills
# Line 8653: Player has 0 kills
# Line 8673: Player has 0 kills
# Line 8675: Player has 0 kills
# Line 8711: Player has 0 kills
# Line 8719: Player has 0 kills
# Line 8766: Player has 0 kills
# Line 8773: Player has 0 kills
# Line 8832: Player has 0 kills
# Line 8839: Player has 0 kills
# Line 8842: Player has 0 kills
# Line 8849: Player has 0 kills
# Line 8878: Player has 0 kills
# Line 8894: Player has 0 kills
# Line 8931: Player has 0 kills
# Line 8947: Player has 0 kills
# Line 8969: Player has 0 kills
# Line 8976: Player has 0 kills
# Line 8977: Player has 0 kills
# Line 8981: Player has 0 kills
# Line 8992: Player has 0 kills
# Line 8996: Player has 0 kills
# Line 9012: Player has 0 kills
# Line 9026: Player has 0 kills
# Line 9028: Player has 0 kills
# Line 9029: Player has 0 kills
# Line 9039: Player has 0 kills
# Line 9047: Player has 0 kills
# Line 9094: Player has 0 kills
# Line 9101: Player has 0 kills
# Line 9105: Player has 0 kills
# Line 9114: Player has 0 kills
# Line 9162: Player has 0 kills
# Line 9163: Player has 0 kills
# Line 9173: Player has 0 kills
# Line 9180: Player has 0 kills
# Line 9215: Player has 0 kills
# Line 9220: Player has 0 kills
# Line 9229: Player has 0 kills
# Line 9250: Player has 0 kills
# Line 9252: Player has 0 kills
# Line 9282: Player has 0 kills
# Line 9291: Player has 0 kills
# Line 9294: Player has 0 kills
# Line 9296: Player has 0 kills
# Line 9317: Player has 0 kills
# Line 9340: Player has 0 kills
# Line 9347: Player has 0 kills
# Line 9359: Player has 0 kills
# Line 9368: Player has 0 kills
# Line 9374: Player has 0 kills
# Line 9377: Player has 0 kills
# Line 9379: Player has 0 kills
# Line 9380: Player has 0 kills
# Line 9381: Player has 0 kills
# Line 9392: Player has 0 kills
# Line 9395: Player has 0 kills
# Line 9397: Player has 0 kills
# Line 9400: Player has 0 kills
# Line 9412: Player has 0 kills
# Line 9415: Player has 0 kills
# Line 9427: Player has 0 kills
# Line 9454: Player has 0 kills
# Line 9492: Player has 0 kills
# Line 9496: Player has 0 kills
# Line 9581: Player has 0 kills
# Line 9584: Player has 0 kills
# Line 9592: Player has 0 kills
# Line 9595: Player has 0 kills
# Line 9629: Player has 0 kills
# Line 9635: Player has 0 kills
# Line 9636: Player has 0 kills
# Line 9640: Player has 0 kills
# Line 9641: Player has 0 kills
# Line 9655: Player has 0 kills
# Line 9658: Player has 0 kills
# Line 9675: Player has 0 kills
# Line 9703: Player has 0 kills
# Line 9710: Player has 0 kills
# Line 9712: Player has 0 kills
# Line 9741: Player has 0 kills
# Line 9773: Player has 0 kills
# Line 9774: Player has 0 kills
# Line 9783: Player has 0 kills
# Line 9787: Player has 0 kills
# Line 9791: Player has 0 kills
# Line 9841: Player has 0 kills
# Line 9847: Player has 0 kills
# Line 9897: Player has 0 kills
# Line 9907: Player has 0 kills
# Line 9926: Player has 0 kills
# Line 9928: Player has 0 kills
# Line 9929: Player has 0 kills
# Line 9930: Player has 0 kills
# Line 9946: Player has 0 kills
# Line 9963: Player has 0 kills
# Line 9970: Player has 0 kills
# Line 9983: Player has 0 kills
# Line 10005: Player has 0 kills
# Line 10017: Player has 0 kills
# Line 10024: Player has 0 kills
# Line 10046: Player has 0 kills
# Line 10049: Player has 0 kills
# Line 10196: Player has 0 kills

# %%
matches.shape
# Out:
# (10210, 88)

# %%
matches['t_first_kill'].plot(kind = 'hist')

# %% [markdown]
# # sen_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
sen_cnt = {
                'id':0,
                't_sen_cnt_3':0,
                't_sen_cnt_5':0,
                't_sen_cnt_8':0,
                't_sen_cnt_10':0,
                't_sen_cnt_12':0,
                't_sen_cnt_15':0,
                't_sen_cnt_20':0,
                't_sen_cnt_25':0,
                't_sen_cnt_30':0       
                }

sen = pd.DataFrame(columns = [key for key, value in sen_cnt.items()])

for i in range(0, len(matches['sen_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    sen_cnt = {
                'id':0,
                't_sen_cnt_3':0,
                't_sen_cnt_5':0,
                't_sen_cnt_8':0,
                't_sen_cnt_10':0,
                't_sen_cnt_12':0,
                't_sen_cnt_15':0,
                't_sen_cnt_20':0,
                't_sen_cnt_25':0,
                't_sen_cnt_30':0,
                't_sen_rpm_3':0,
                't_sen_rpm_5':0,
                't_sen_rpm_8':0,
                't_sen_rpm_10':0,
                't_sen_rpm_12':0,
                't_sen_rpm_15':0,
                't_sen_rpm_20':0,
                't_sen_rpm_25':0,
                't_sen_rpm_30':0    
                }
    try: 
        if matches['sen_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['sen_log'][i])):
                for timeStamp in timeStamps:
                    if matches['sen_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_sen_cnt_" + timeStamp
                        varName_rpm = "t_sen_rpm_" + timeStamp
                        sen_cnt[varName_cnt] += 1
                        sen_cnt[varName_rpm] += 1 / float(timeStamp)
            sen_cnt['id'] = matches['id'][i]
            senRow = pd.DataFrame.from_dict(sen_cnt, orient = 'index').transpose()
            sen = sen.append(senRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed
# 6000 Matches has been processed
# 7000 Matches has been processed
# 8000 Matches has been processed
# 9000 Matches has been processed
# 10000 Matches has been processed

# %%
matches = matches.merge(sen, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (10214, 106)

# %% [markdown]
# # Возникают новые записи в таблице, хотя используется inner join. С чем это может быть связано?

# %% [markdown]
# # obs_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
obs_cnt = {
                'id':0,
                't_obs_cnt_3':0,
                't_obs_cnt_5':0,
                't_obs_cnt_8':0,
                't_obs_cnt_10':0,
                't_obs_cnt_12':0,
                't_obs_cnt_15':0,
                't_obs_cnt_20':0,
                't_obs_cnt_25':0,
                't_obs_cnt_30':0       
                }

obs = pd.DataFrame(columns = [key for key, value in obs_cnt.items()])

for i in range(0, len(matches['obs_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    obs_cnt = {
                'id':0,
                't_obs_cnt_3':0,
                't_obs_cnt_5':0,
                't_obs_cnt_8':0,
                't_obs_cnt_10':0,
                't_obs_cnt_12':0,
                't_obs_cnt_15':0,
                't_obs_cnt_20':0,
                't_obs_cnt_25':0,
                't_obs_cnt_30':0,
                't_obs_rpm_3':0,
                't_obs_rpm_5':0,
                't_obs_rpm_8':0,
                't_obs_rpm_10':0,
                't_obs_rpm_12':0,
                't_obs_rpm_15':0,
                't_obs_rpm_20':0,
                't_obs_rpm_25':0,
                't_obs_rpm_30':0    
                }
    try: 
        if matches['obs_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['obs_log'][i])):
                for timeStamp in timeStamps:
                    if matches['obs_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_obs_cnt_" + timeStamp
                        varName_rpm = "t_obs_rpm_" + timeStamp
                        obs_cnt[varName_cnt] += 1
                        obs_cnt[varName_rpm] += 1 / float(timeStamp)
            obs_cnt['id'] = matches['id'][i]
            obsRow = pd.DataFrame.from_dict(obs_cnt, orient = 'index').transpose()
            obs = obs.append(obsRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed
# 6000 Matches has been processed
# 7000 Matches has been processed
# 8000 Matches has been processed
# 9000 Matches has been processed
# 10000 Matches has been processed

# %%
matches = matches.merge(obs, left_on='id', right_on='id', how='inner')
print matches.shape
# Out:
# (10238, 124)

# %% [markdown]
# # runes_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
runes_cnt = {
                'id':0,
                't_runes_cnt_3':0,
                't_runes_cnt_5':0,
                't_runes_cnt_8':0,
                't_runes_cnt_10':0,
                't_runes_cnt_12':0,
                't_runes_cnt_15':0,
                't_runes_cnt_20':0,
                't_runes_cnt_25':0,
                't_runes_cnt_30':0       
                }

runes = pd.DataFrame(columns = [key for key, value in runes_cnt.items()])

for i in range(0, len(matches['runes_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    runes_cnt = {
                'id':0,
                't_runes_cnt_3':0,
                't_runes_cnt_5':0,
                't_runes_cnt_8':0,
                't_runes_cnt_10':0,
                't_runes_cnt_12':0,
                't_runes_cnt_15':0,
                't_runes_cnt_20':0,
                't_runes_cnt_25':0,
                't_runes_cnt_30':0,
                't_runes_rpm_3':0,
                't_runes_rpm_5':0,
                't_runes_rpm_8':0,
                't_runes_rpm_10':0,
                't_runes_rpm_12':0,
                't_runes_rpm_15':0,
                't_runes_rpm_20':0,
                't_runes_rpm_25':0,
                't_runes_rpm_30':0    
                }
    try:
        if matches['runes_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['runes_log'][i])):
                for timeStamp in timeStamps:
                    if matches['runes_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_runes_cnt_" + timeStamp
                        varName_rpm = "t_runes_rpm_" + timeStamp
                        runes_cnt[varName_cnt] += 1
                        runes_cnt[varName_rpm] += 1 / float(timeStamp)
            runes_cnt['id'] = matches['id'][i]
            runesRow = pd.DataFrame.from_dict(runes_cnt, orient = 'index').transpose()
            runes = runes.append(runesRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed
# 6000 Matches has been processed
# 7000 Matches has been processed
# 8000 Matches has been processed
# 9000 Matches has been processed
# 10000 Matches has been processed

# %%
matches = matches.merge(runes, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (10718, 142)

# %% [markdown]
# # buyback_log

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
buyback_cnt = {
                'id':0,
                't_buyback_cnt_3':0,
                't_buyback_cnt_5':0,
                't_buyback_cnt_8':0,
                't_buyback_cnt_10':0,
                't_buyback_cnt_12':0,
                't_buyback_cnt_15':0,
                't_buyback_cnt_20':0,
                't_buyback_cnt_25':0,
                't_buyback_cnt_30':0       
                }

buyback = pd.DataFrame(columns = [key for key, value in buyback_cnt.items()])

for i in range(0, len(matches['buyback_log'])):
    
    if (i % 1000 == 0):
        print "%s Matches has been processed" %i
    
    buyback_cnt = {
                'id':0,
                't_buyback_cnt_3':0,
                't_buyback_cnt_5':0,
                't_buyback_cnt_8':0,
                't_buyback_cnt_10':0,
                't_buyback_cnt_12':0,
                't_buyback_cnt_15':0,
                't_buyback_cnt_20':0,
                't_buyback_cnt_25':0,
                't_buyback_cnt_30':0,
                't_buyback_rpm_3':0,
                't_buyback_rpm_5':0,
                't_buyback_rpm_8':0,
                't_buyback_rpm_10':0,
                't_buyback_rpm_12':0,
                't_buyback_rpm_15':0,
                't_buyback_rpm_20':0,
                't_buyback_rpm_25':0,
                't_buyback_rpm_30':0    
                }
    try: 
        if matches['buyback_log'][i] is not None:
            cumulative = 0
            for j in range(0, len(matches['buyback_log'][i])):
                for timeStamp in timeStamps:
                    if matches['buyback_log'][i][j]['time'] < int(timeStamp) * 60:
                        varName_cnt = "t_buyback_cnt_" + timeStamp
                        varName_rpm = "t_buyback_rpm_" + timeStamp
                        buyback_cnt[varName_cnt] += 1
                        buyback_cnt[varName_rpm] += 1 / float(timeStamp)
            buyback_cnt['id'] = matches['id'][i]
            buybackRow = pd.DataFrame.from_dict(buyback_cnt, orient = 'index').transpose()
            buyback = buyback.append(buybackRow, ignore_index=True)
        else: print "Line %s: Log does not exists" %i
    except Exception:
        print "Line %s: Unknown error" %i
# Out:
# 0 Matches has been processed
# 1000 Matches has been processed
# 2000 Matches has been processed
# 3000 Matches has been processed
# 4000 Matches has been processed
# 5000 Matches has been processed
# 6000 Matches has been processed
# 7000 Matches has been processed
# 8000 Matches has been processed
# 9000 Matches has been processed
# 10000 Matches has been processed

# %%
matches = matches.merge(buyback, left_on='id', right_on='id', how='inner')
matches.shape
# Out:
# (141278, 160)

# %%
buyback.shape
# Out:
# (10718, 19)

# %% [markdown]
# # Откуда 4000 новых записей после Join, при условии, что таблица buyback содержит 10908 записей?

# %% [markdown]
# # Hero statistics

# %%
urlHeroes = "https://api.opendota.com/api/heroStats"

# %%
response = urllib2.urlopen(urlHeroes)
jsonResponse = response.read()
dictData = json.loads(jsonResponse)

# %%
heroesList = list()
heroAttr = [
            'id',
            'localized_name', 
            'attack_type',
            'pro_ban', 
            'pro_pick', 
            'pro_win', 
            'primary_attr', 
            'roles'
            ]
heroRolesList = [
                'Carry',
                'Disabler',
                'Initiator',
                'Jungler',
                'Support',
                'Durable',
                'Nuker',
                'Escape',
                'Pusher'
                ]

for heroId in range(0, len(dictData) - 1):    
    heroRaw = dict()
    
    for heroRole in heroRolesList:
        heroRaw[heroRole] = 0
    for key, value in dictData[heroId].iteritems():
        if key in heroAttr:
            heroRaw[key] = dictData[heroId][key]
            if key == 'roles':
                for heroRole in dictData[heroId][key]:
                    heroRaw[heroRole] = 1
    del heroRaw['roles']                
    heroesList.append(heroRaw)

# %%
heroes = pd.DataFrame(heroesList)
print heroes.shape
heroes.head()
# Out:
# (112, 16)
#    Carry  Disabler  Durable  Escape  Initiator  Jungler  Nuker  Pusher  \
# 0      1         0        0       1          0        0      1       0
# 1      0         1        1       0          1        1      0       0
# 2      0         1        1       0          0        0      1       0
# 3      1         1        0       0          1        1      1       0
# 4      0         1        0       0          0        1      1       0
#
#    Support attack_type  id  localized_name primary_attr  pro_ban  pro_pick  \
# 0        0       Melee   1       Anti-Mage          agi     67.0      48.0
# 1        0       Melee   2             Axe          str    210.0     196.0
# 2        1      Ranged   3            Bane          int      1.0      19.0
# 3        0       Melee   4     Bloodseeker          agi      6.0      17.0
# 4        1      Ranged   5  Crystal Maiden          int     57.0     412.0
#
#    pro_win
# 0     22.0
# 1    105.0
# 2     10.0
# 3      7.0
# 4    230.0

# %%
matches= matches.merge(heroes, left_on = 'hero_id', right_on = 'id', how = 'inner')
matches.shape
# Out:
# (141134, 176)

# %%
matches.head()
# Out:
#    account_id  assists attack_type_x  \
# 0    89166519       19        Ranged
# 1   135878232       13        Ranged
# 2    89166519        4        Ranged
# 3    90892734       14        Ranged
# 4    90892734       12        Ranged
#
#                                          buyback_log  camps_stacked  cluster  \
# 0                                                 []            0.0      224
# 1                                                 []            0.0      224
# 2                                                 []            0.0      224
# 3  [{u'slot': 4, u'type': u'buyback_log', u'playe...            0.0      224
# 4  [{u'slot': 9, u'type': u'buyback_log', u'playe...            0.0      224
#
#    creeps_stacked  deaths  duration  first_blood_time   ...     Nuker  Pusher  \
# 0             0.0       3      1454                 0   ...         1       0
# 1             0.0       2      1479                65   ...         1       0
# 2             0.0       6      1524                 3   ...         1       0
# 3             0.0       6      2983                 4   ...         1       0
# 4             0.0       4      1859                76   ...         1       0
#
#    Support  attack_type_y  id_y localized_name_y  primary_attr_y pro_ban  \
# 0        1         Ranged    20  Vengeful Spirit             agi    97.0
# 1        1         Ranged    20  Vengeful Spirit             agi    97.0
# 2        1         Ranged    20  Vengeful Spirit             agi    97.0
# 3        1         Ranged    20  Vengeful Spirit             agi    97.0
# 4        1         Ranged    20  Vengeful Spirit             agi    97.0
#
#   pro_pick  pro_win
# 0    219.0    106.0
# 1    219.0    106.0
# 2    219.0    106.0
# 3    219.0    106.0
# 4    219.0    106.0
#
# [5 rows x 176 columns]

# %%
matches.tail()
# Out:
#         account_id  assists attack_type_x  \
# 141129    82262664       21        Ranged
# 141130   112377459        0        Ranged
# 141131   117990312       21        Ranged
# 141132   101450083        6        Ranged
# 141133    50828662        9        Ranged
#
#                                               buyback_log  camps_stacked  \
# 141129  [{u'slot': 5, u'type': u'buyback_log', u'playe...            1.0
# 141130                                                 []            0.0
# 141131  [{u'slot': 3, u'type': u'buyback_log', u'playe...            2.0
# 141132                                                 []            1.0
# 141133                                                 []            0.0
#
#         cluster  creeps_stacked  deaths  duration  first_blood_time   ...     \
# 141129      136             3.0      10      3822               219   ...
# 141130      153             0.0       3       999               160   ...
# 141131      224             5.0       9      3396               143   ...
# 141132      132             2.0       5      3149               251   ...
# 141133      123             0.0       6      1868               200   ...
#
#         Nuker  Pusher  Support  attack_type_y  id_y    localized_name_y  \
# 141129      1       0        1         Ranged    68  Ancient Apparition
# 141130      1       0        1         Ranged    68  Ancient Apparition
# 141131      1       0        1         Ranged    68  Ancient Apparition
# 141132      0       0        0         Ranged    59              Huskar
# 141133      1       0        0         Ranged   105             Techies
#
#         primary_attr_y pro_ban pro_pick  pro_win
# 141129             int    16.0      9.0      2.0
# 141130             int    16.0      9.0      2.0
# 141131             int    16.0      9.0      2.0
# 141132             str     6.0      3.0      2.0
# 141133             int     NaN      NaN      NaN
#
# [5 rows x 176 columns]

# %% [markdown]
# # EXP_RPM

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
var = 'experience'
varTemplate = 't_' + var + '_'
for timeStamp in timeStamps:
    varName_cnt = varTemplate + 'cnt_' + timeStamp
    varName_rpm = varTemplate + 'rpm_' + timeStamp
    matches[varName_rpm] = matches[varName_cnt] / float(timeStamp)

# %% [markdown]
# # GOLD_RPM

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
var = 'gold'
varTemplate = 't_' + var + '_'
for timeStamp in timeStamps:
    varName_cnt = varTemplate + 'cnt_' + timeStamp
    varName_rpm = varTemplate + 'rpm_' + timeStamp
    matches[varName_rpm] = matches[varName_cnt] / float(timeStamp)

# %% [markdown]
# # LASTHITS_RPM

# %%
timeStamps = [
              '3',
              '5',
              '8',
              '10',
              '12',
              '15',
              '20',
              '25',
              '30'
             ]
var = 'lasthits'
varTemplate = 't_' + var + '_'
for timeStamp in timeStamps:
    varName_cnt = varTemplate + 'cnt_' + timeStamp
    varName_rpm = varTemplate + 'rpm_' + timeStamp
    matches[varName_rpm] = matches[varName_cnt] / float(timeStamp)

# %%
for col in list(matches):
    print col
# Out:
# account_id
# assists
# attack_type_x
# buyback_log
# camps_stacked
# cluster
# creeps_stacked
# deaths
# duration
# first_blood_time
# gold_per_min
# gold_spent
# hero_damage
# hero_healing
# hero_id
# kills_log
# leagueid
# leaguename
# localized_name_x
# match_id
# obs_log
# ping_log
# player_slot
# primary_attr_x
# purchase_log
# role_log
# runes_log
# sen_log
# start_time
# stuns
# t_experience_cnt_10
# t_experience_cnt_12
# t_experience_cnt_15
# t_experience_cnt_20
# t_experience_cnt_25
# t_experience_cnt_3
# t_experience_cnt_30
# t_experience_cnt_5
# t_experience_cnt_8
# t_gold_cnt_10
# t_gold_cnt_12
# t_gold_cnt_15
# t_gold_cnt_20
# t_gold_cnt_25
# t_gold_cnt_3
# t_gold_cnt_30
# t_gold_cnt_5
# t_gold_cnt_8
# t_lasthits_cnt_10
# t_lasthits_cnt_12
# t_lasthits_cnt_15
# t_lasthits_cnt_20
# t_lasthits_cnt_25
# t_lasthits_cnt_3
# t_lasthits_cnt_30
# t_lasthits_cnt_5
# t_lasthits_cnt_8
# team_id
# tower_damage
# win
# xp_per_min
# id_x
# datetime
# t_first_kill
# t_item_aether_lens
# t_item_arcane_boots
# t_item_black_king_bar
# t_item_blade_mail
# t_item_blink
# t_item_boots
# t_item_bottle
# t_item_desolator
# t_item_echo_sabre
# t_item_force_staff
# t_item_hand_of_midas
# t_item_hurricane_pike
# t_item_invis_sword
# t_item_magic_wand
# t_item_manta
# t_item_phase_boots
# t_item_power_treads
# t_item_ring_of_aquila
# t_item_silver_edge
# t_item_sphere
# t_item_tranquil_boots
# t_item_travel_boots
# t_item_ultimate_scepter
# t_item_wind_lace
# t_sen_cnt_10
# t_sen_cnt_12
# t_sen_cnt_15
# t_sen_cnt_20
# t_sen_cnt_25
# t_sen_cnt_3
# t_sen_cnt_30
# t_sen_cnt_5
# t_sen_cnt_8
# t_sen_rpm_10
# t_sen_rpm_12
# t_sen_rpm_15
# t_sen_rpm_20
# t_sen_rpm_25
# t_sen_rpm_3
# t_sen_rpm_30
# t_sen_rpm_5
# t_sen_rpm_8
# t_obs_cnt_10
# t_obs_cnt_12
# t_obs_cnt_15
# t_obs_cnt_20
# t_obs_cnt_25
# t_obs_cnt_3
# t_obs_cnt_30
# t_obs_cnt_5
# t_obs_cnt_8
# t_obs_rpm_10
# t_obs_rpm_12
# t_obs_rpm_15
# t_obs_rpm_20
# t_obs_rpm_25
# t_obs_rpm_3
# t_obs_rpm_30
# t_obs_rpm_5
# t_obs_rpm_8
# t_runes_cnt_10
# t_runes_cnt_12
# t_runes_cnt_15
# t_runes_cnt_20
# t_runes_cnt_25
# t_runes_cnt_3
# t_runes_cnt_30
# t_runes_cnt_5
# t_runes_cnt_8
# t_runes_rpm_10
# t_runes_rpm_12
# t_runes_rpm_15
# t_runes_rpm_20
# t_runes_rpm_25
# t_runes_rpm_3
# t_runes_rpm_30
# t_runes_rpm_5
# t_runes_rpm_8
# t_buyback_cnt_10
# t_buyback_cnt_12
# t_buyback_cnt_15
# t_buyback_cnt_20
# t_buyback_cnt_25
# t_buyback_cnt_3
# t_buyback_cnt_30
# t_buyback_cnt_5
# t_buyback_cnt_8
# t_buyback_rpm_10
# t_buyback_rpm_12
# t_buyback_rpm_15
# t_buyback_rpm_20
# t_buyback_rpm_25
# t_buyback_rpm_3
# t_buyback_rpm_30
# t_buyback_rpm_5
# t_buyback_rpm_8
# Carry
# Disabler
# Durable
# Escape
# Initiator
# Jungler
# Nuker
# Pusher
# Support
# attack_type_y
# id_y
# localized_name_y
# primary_attr_y
# pro_ban
# pro_pick
# pro_win
# t_experience_rpm_3
# t_experience_rpm_5
# t_experience_rpm_8
# t_experience_rpm_10
# t_experience_rpm_12
# t_experience_rpm_15
# t_experience_rpm_20
# t_experience_rpm_25
# t_experience_rpm_30
# t_gold_rpm_3
# t_gold_rpm_5
# t_gold_rpm_8
# t_gold_rpm_10
# t_gold_rpm_12
# t_gold_rpm_15
# t_gold_rpm_20
# t_gold_rpm_25
# t_gold_rpm_30
# t_lasthits_rpm_3
# t_lasthits_rpm_5
# t_lasthits_rpm_8
# t_lasthits_rpm_10
# t_lasthits_rpm_12
# t_lasthits_rpm_15
# t_lasthits_rpm_20
# t_lasthits_rpm_25
# t_lasthits_rpm_30

# %% [markdown]
# # Заметка: после join появляются id_x и id_y - айдишники правых и левых таблиц

# %%
print matches['id_x'].unique().size
# Out:
# 10064

# %%
print matches['id_y'].unique().size
# Out:
# 112

# %% [markdown]
# # Используем id_x в качестве уникального id.
# Аналог SQL select distinct id_x from matches (Удаляем дубликаты)

# %%
matches.drop_duplicates(subset = 'id_x', inplace = True)

# %%
matches.shape
# Out:
# (10064, 203)

# %%
matchesWithoutLogs = matches.drop(labels = ['buyback_log', 'kills_log', 'obs_log', 'ping_log', 'purchase_log', 'role_log', 'runes_log', 'sen_log'], axis = 1)

# %%
matchesWithoutLogs.to_csv('ABT_20_04_2017_withKills.csv', na_rep = 'NaN', sep = ';')
